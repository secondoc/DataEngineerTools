# %% [markdown]
# #  Consignes
#
# ## Description
#
# Ouvrir le fichier ks-projects-201801.csv, il recense environ 100 000 projets KickStarter. Intégrer les données directement avec L'API Python dans une base de données Mongo.
#
# Il conviendra de bien spécifier manuellement l'ID du document. Pensez aussi à bien formatter le type des données pour profiter des méthodes implémentées par Mongo. L'ensemble de données n'est pas forcément nécessaire, c'est à vous de créer votre modèle de données.
#
# ## Questions
#
# - 1) Récupérer les 5 projets ayant reçu le plus de promesse de dons.
# - 2) Compter le nombre de projets ayant atteint leur but.
# - 3) Compter le nombre de projets pour chaque catégorie.
# - 4) Compter le nombre de projets français ayant été instanciés avant 2016.
# - 5) Récupérer les projets américains ayant demandé plus de 200 000 dollars.
# - 6) Compter le nombre de projet ayant "Sport" dans leur nom

# %%
import pandas as pd
import pymongo

# %%
client = pymongo.MongoClient("mongo")
database = client['exercices']
collection = database['kickstarter']

# %%
df_ks = pd.read_csv("./data/ks-projects-201801-sample.csv")
df_ks.head()
# Out:
# /root/.local/share/virtualenvs/code-AFz48Hjb/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (6,8,10,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#            ID                                               name  \
# 0   872782264    Scott Cooper's Solo CD "A Leg Trick" (Canceled)
# 1  1326492673                                    Ohceola jewelry
# 2  1688410639  Sluff Off & Harald: Two latest EGGs are Classi...
# 3   156812982  SketchPlanner: Create and Plan- all in one bea...
# 4  1835968190    Proven sales with custom motorcycle accessories
#
#          category main_category currency    deadline   goal  \
# 0            Rock         Music      USD  2011-09-16   2000
# 1         Fashion       Fashion      USD  2012-08-22  18000
# 2  Tabletop Games         Games      USD  2016-07-19   2000
# 3       Art Books    Publishing      USD  2017-09-27  13000
# 4       Sculpture           Art      CAD  2016-02-24   5000
#
#               launched pledged       state backers country usd pledged  \
# 0  2011-08-17 06:31:31    1145    canceled      24      US        1145
# 1  2012-07-23 20:46:48    1851      failed      28      US        1851
# 2  2016-07-01 21:55:54    7534  successful     254      US        3796
# 3  2017-08-28 15:47:02   16298  successful     367      US        2670
# 4  2016-01-25 17:37:10       1      failed       1      CA    0.708148
#
#    usd_pledged_real
# 0       1145.000000
# 1       1851.000000
# 2       7534.000000
# 3      16298.000000
# 4          0.738225

# %% [markdown]
# Ce warning intervient lorsque pandas n'arrive pas à inférer le type de données. Il est sympa il précise les colones 6,8,10,12.

# %%
df_ks.columns[[6,8,10,12]]
# Out:
# Index(['goal', 'pledged', 'backers', 'usd pledged'], dtype='object')

# %% [markdown]
# ## Question 0

# %% [markdown]
# ### Netoyer les données

# %%
df_ks.dtypes
# Out:
# ID                    int64
# name                 object
# category             object
# main_category        object
# currency             object
# deadline             object
# goal                 object
# launched             object
# pledged              object
# state                object
# backers              object
# country              object
# usd pledged          object
# usd_pledged_real    float64
# dtype: object

# %%
pd.to_numeric(df_ks['goal'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "2014-04-17"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-555f2a8d9545> in <module>
# ----> 1 pd.to_numeric(df_ks['goal'])
#
# ~/.local/share/virtualenvs/code-AFz48Hjb/lib/python3.8/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     150         coerce_numeric = errors not in ("ignore", "raise")
#     151         try:
# --> 152             values = lib.maybe_convert_numeric(
#     153                 values, set(), coerce_numeric=coerce_numeric
#     154             )
#
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "2014-04-17" at position 66141

# %% [markdown]
# On remarque avec l'erreur si dessus qu'il y a un problème à la position 66141. A la place du goal, il y a des données décalées (ici sûrement la valeur deadline), on va le vérifier ci-dessous.

# %%
df_ks.iloc[66141,:]
# Out:
# ID                                        85964225
# name                Debut Album from Michael Adam
# category                          Grace is Leaving
# main_category                           Indie Rock
# currency                                     Music
# deadline                                       USD
# goal                                    2014-04-17
# launched                                     700.0
# pledged                        2014-04-02 21:56:35
# state                                        850.0
# backers                                 successful
# country                                         32
# usd pledged                                     US
# usd_pledged_real                               850
# Name: 66141, dtype: object

# %% [markdown]
# On remarque bien que tout est décalé à cause du titre qui est sur 2 lignes ! On va donc supprimer la ligne car il nous manque la donnée usd_pleadged_real.

# %%
df_ks.drop(66141,0,inplace=True)

# %% [markdown]
# On teste alors la fonction précédente !

# %%
df_ks=df_ks.astype({"goal":"float64"})

# %%
df_ks.drop(['currency', 'deadline', 'pledged', 'backers', 'usd pledged'], axis='columns', inplace=True)
df_ks.head(5)
# Out:
#            ID                                               name  \
# 0   872782264    Scott Cooper's Solo CD "A Leg Trick" (Canceled)
# 1  1326492673                                    Ohceola jewelry
# 2  1688410639  Sluff Off & Harald: Two latest EGGs are Classi...
# 3   156812982  SketchPlanner: Create and Plan- all in one bea...
# 4  1835968190    Proven sales with custom motorcycle accessories
#
#          category main_category     goal             launched       state  \
# 0            Rock         Music   2000.0  2011-08-17 06:31:31    canceled
# 1         Fashion       Fashion  18000.0  2012-07-23 20:46:48      failed
# 2  Tabletop Games         Games   2000.0  2016-07-01 21:55:54  successful
# 3       Art Books    Publishing  13000.0  2017-08-28 15:47:02  successful
# 4       Sculpture           Art   5000.0  2016-01-25 17:37:10      failed
#
#   country  usd_pledged_real
# 0      US       1145.000000
# 1      US       1851.000000
# 2      US       7534.000000
# 3      US      16298.000000
# 4      CA          0.738225

# %% [markdown]
# ### Importer les données

# %%
dictionnaire=df_ks.to_dict('record')
# Out:
# /root/.local/share/virtualenvs/code-AFz48Hjb/lib/python3.8/site-packages/pandas/core/frame.py:1485: FutureWarning: Using short name for 'orient' is deprecated. Only the options: ('dict', list, 'series', 'split', 'records', 'index') will be used in a future version. Use one of the above to silence this warning.
#   warnings.warn(

# %%
dictionnaire
# Out:
# [{'ID': 872782264,
#   'name': 'Scott Cooper\'s Solo CD "A Leg Trick" (Canceled)',
#   'category': 'Rock',
#   'main_category': 'Music',
#   'goal': 2000.0,
#   'launched': '2011-08-17 06:31:31',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 1145.0},
#  {'ID': 1326492673,
#   'name': 'Ohceola jewelry',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'goal': 18000.0,
#   'launched': '2012-07-23 20:46:48',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1851.0},
#  {'ID': 1688410639,
#   'name': 'Sluff Off & Harald: Two latest EGGs are Classics "old & new"',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'goal': 2000.0,
#   'launched': '2016-07-01 21:55:54',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 7534.0},
#  {'ID': 156812982,
#   'name': 'SketchPlanner: Create and Plan- all in one beautiful book!',
#   'category': 'Art Books',
#   'main_category': 'Publishing',
#   'goal': 13000.0,
#   'launched': '2017-08-28 15:47:02',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 16298.0},
#  {'ID': 1835968190,
#   'name': 'Proven sales with custom motorcycle accessories',
#   'category': 'Sculpture',
#   'main_category': 'Art',
#   'goal': 5000.0,
#   'launched': '2016-01-25 17:37:10',
#   'state': 'failed',
#   'country': 'CA',
#   'usd_pledged_real': 0.7382253063635021},
#  {'ID': 1771789139,
#   'name': 'Room For Growth!',
#   'category': 'Couture',
#   'main_category': 'Fashion',
#   'goal': 2000.0,
#   'launched': '2016-04-11 18:15:00',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 6.0},
#  {'ID': 1301627822,
#   'name': 'Build a mini Udemy with Laravel and Vuejs',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'goal': 3000.0,
#   'launched': '2017-12-12 01:37:26',
#   'state': 'live',
#   'country': 'CA',
#   'usd_pledged_real': 123.81180605479669},
#  {'ID': 881336601,
#   'name': 'Applitizer',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'goal': 100000.0,
#   'launched': '2017-07-21 16:50:05',
#   'state': 'failed',
#   'country': 'HK',
#   'usd_pledged_real': 127.83146699391523},
#  {'ID': 1669374237,
#   'name': 'Help I Am Wolves fund their first album "ABCD" on 12" vinyl!',
#   'category': 'Music',
#   'main_category': 'Music',
#   'goal': 1000.0,
#   'launched': '2017-10-27 16:55:47',
#   'state': 'successful',
#   'country': 'BE',
#   'usd_pledged_real': 1720.2104175473205},
#  {'ID': 556821416,
#   'name': 'Eco  Bamboo Underwear funding....GOT WOOD ?',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'goal': 9500.0,
#   'launched': '2012-11-13 10:58:34',
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged_real': 1953.6728081628705},
#  {'ID': 160394496,
#   'name': 'SHAKTI: The Power of Woman',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 15000.0,
#   'launched': '2012-01-13 16:27:16',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 18361.89},
#  {'ID': 1248488072,
#   'name': 'Coast to Coaster',
#   'category': 'Print',
#   'main_category': 'Journalism',
#   'goal': 25000.0,
#   'launched': '2017-05-07 06:05:42',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1.0},
#  {'ID': 895565490,
#   'name': 'Frostbite Gaming - Minecraft HUB',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 400.0,
#   'launched': '2014-10-17 11:25:49',
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged_real': 15.695876693192696},
#  {'ID': 1165822076,
#   'name': 'Support Ramsort album',
#   'category': 'Rock',
#   'main_category': 'Music',
#   'goal': 150000.0,
#   'launched': '2015-04-03 14:24:19',
#   'state': 'failed',
#   'country': 'NO',
#   'usd_pledged_real': 1.3387776959635849},
#  {'ID': 424612381,
#   'name': 'Red No. 95 Issue 3',
#   'category': 'Comic Books',
#   'main_category': 'Comics',
#   'goal': 800.0,
#   'launched': '2017-07-11 08:16:21',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 955.0},
#  {'ID': 1182908609,
#   'name': 'Alice In Wonderland!',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'goal': 220.0,
#   'launched': '2012-05-16 05:37:08',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 320.0},
#  {'ID': 206040356,
#   'name': 'Un piano : 150 Pas',
#   'category': 'Performances',
#   'main_category': 'Dance',
#   'goal': 1500.0,
#   'launched': '2017-07-05 21:52:43',
#   'state': 'successful',
#   'country': 'CA',
#   'usd_pledged_real': 1274.0961363448332},
#  {'ID': 396454289,
#   'name': 'Operation Penumbra: A WWII Supernatural Adventure, Vol. 1',
#   'category': 'Comics',
#   'main_category': 'Comics',
#   'goal': 15000.0,
#   'launched': '2013-12-18 23:19:02',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 5035.0},
#  {'ID': 1522195027,
#   'name': 'Emma Rae',
#   'category': 'Drama',
#   'main_category': 'Film & Video',
#   'goal': 12000.0,
#   'launched': '2017-06-27 18:00:25',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 13415.0},
#  {'ID': 1429288669,
#   'name': 'Strange Occurrences: Performances for Non-Theater Spaces',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'goal': 3000.0,
#   'launched': '2010-07-23 23:30:10',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 3080.98},
#  {'ID': 1441999253,
#   'name': 'Ancient Ruins II Base Series',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'goal': 1800.0,
#   'launched': '2014-10-22 14:58:46',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 5630.95},
#  {'ID': 1202442815,
#   'name': 'The Craziest Thing Webseries',
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'goal': 30000.0,
#   'launched': '2014-01-22 00:13:15',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 300.0},
#  {'ID': 2116917173,
#   'name': 'Look UP! To this nice shirt!',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'goal': 3700.0,
#   'launched': '2012-09-26 06:15:44',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 203.0},
#  {'ID': 2117684680,
#   'name': 'Ghost Nest: Giving the Power of Design Back to the Consumer (Canceled)',
#   'category': 'Design',
#   'main_category': 'Design',
#   'goal': 18729.0,
#   'launched': '2010-10-08 01:29:29',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 1781.0},
#  {'ID': 350628546,
#   'name': 'Elli (Canceled)',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'goal': 5000.0,
#   'launched': '2014-09-04 00:10:14',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 121.0},
#  {'ID': 35969505,
#   'name': 'States, Firms, & Households: the search for equilibrium (2)',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 100.0,
#   'launched': '2015-12-23 07:35:24',
#   'state': 'canceled',
#   'country': 'CA',
#   'usd_pledged_real': 0.0},
#  {'ID': 1849047042,
#   'name': "Central Florida Artisans' Guild: Community Growth",
#   'category': 'DIY',
#   'main_category': 'Crafts',
#   'goal': 2000.0,
#   'launched': '2015-04-22 18:59:35',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 121.0},
#  {'ID': 295864582,
#   'name': 'Frankenstein Soft Enamel Pin',
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'goal': 215.0,
#   'launched': '2017-09-22 22:25:58',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 18.0},
#  {'ID': 496463082,
#   'name': 'qualMeter XT: Greater Experience on Cable/Charger Testing',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'goal': 5000.0,
#   'launched': '2017-05-06 15:13:17',
#   'state': 'successful',
#   'country': 'CA',
#   'usd_pledged_real': 7887.334369679473},
#  {'ID': 1390262683,
#   'name': 'Candy Coburn - "THE GOOD LIFE" New Soul Rockin\' Studio Album',
#   'category': 'Music',
#   'main_category': 'Music',
#   'goal': 15000.0,
#   'launched': '2016-05-10 12:43:24',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 15530.0},
#  {'ID': 1041882251,
#   'name': "Gentlemen's Bar",
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'goal': 4000.0,
#   'launched': '2016-06-16 20:31:11',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 613.0},
#  {'ID': 1130940376,
#   'name': 'A Sickle Life',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 5000.0,
#   'launched': '2016-06-01 15:15:40',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 60.0},
#  {'ID': 186326896,
#   'name': 'NYC Type',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'goal': 10000.0,
#   'launched': '2012-10-11 00:28:31',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 10106.0},
#  {'ID': 1025722498,
#   'name': 'PatentSlice.com-Automated Patent Drill-Down & Analysis Tool',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'goal': 5000.0,
#   'launched': '2017-02-21 21:37:27',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'ID': 1493170888,
#   'name': 'The Birdsongs - New CD Project',
#   'category': 'Music',
#   'main_category': 'Music',
#   'goal': 5000.0,
#   'launched': '2011-03-18 02:50:18',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 6357.0},
#  {'ID': 1007463174,
#   'name': 'Brazilian pop artist Kiko London Tour support',
#   'category': 'Music',
#   'main_category': 'Music',
#   'goal': 8000.0,
#   'launched': '2017-03-14 19:22:11',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1.0},
#  {'ID': 2143760539,
#   'name': 'Emissary - Tabletop RPG',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'goal': 5000.0,
#   'launched': '2016-02-20 15:46:23',
#   'state': 'successful',
#   'country': 'GB',
#   'usd_pledged_real': 13174.888019103872},
#  {'ID': 2062002375,
#   'name': 'Desktop Museum of Card Art',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 1600.0,
#   'launched': '2014-03-12 22:33:56',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 587.0},
#  {'ID': 1183084584,
#   'name': 'Act for Change: Healing Minds',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 16000.0,
#   'launched': '2014-07-14 22:47:13',
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged_real': 2733.827358301622},
#  {'ID': 1977195934,
#   'name': 'Book: Outrageously (un)loved - The fight against selfhatred',
#   'category': 'Nonfiction',
#   'main_category': 'Publishing',
#   'goal': 900.0,
#   'launched': '2015-01-29 23:17:48',
#   'state': 'canceled',
#   'country': 'NL',
#   'usd_pledged_real': 0.0},
#  {'ID': 1035882318,
#   'name': 'Help match our 2nd NEA grant for Glory Denied',
#   'category': 'Classical Music',
#   'main_category': 'Music',
#   'goal': 2500.0,
#   'launched': '2015-10-26 14:06:42',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 2650.0},
#  {'ID': 1021441525,
#   'name': 'The Alchemy of Art Book',
#   'category': 'Mixed Media',
#   'main_category': 'Art',
#   'goal': 7770.0,
#   'launched': '2016-11-28 02:06:47',
#   'state': 'canceled',
#   'country': 'CA',
#   'usd_pledged_real': 18.499334023975138},
#  {'ID': 1691723287,
#   'name': 'The Om Space',
#   'category': 'Civic Design',
#   'main_category': 'Design',
#   'goal': 15000.0,
#   'launched': '2016-06-08 18:13:45',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1512.0},
#  {'ID': 680665134,
#   'name': 'Open Source Gemini Simulator',
#   'category': 'Gaming Hardware',
#   'main_category': 'Games',
#   'goal': 1675.0,
#   'launched': '2017-07-18 19:37:33',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 1685.0},
#  {'ID': 1864901261,
#   'name': 'Tenabris Ides',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'goal': 1500.0,
#   'launched': '2015-02-14 03:53:39',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 16.0},
#  {'ID': 519449839,
#   'name': 'Johnny P - Resurrected (Album)',
#   'category': 'Hip-Hop',
#   'main_category': 'Music',
#   'goal': 750.0,
#   'launched': '2013-07-08 22:54:55',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 26.0},
#  {'ID': 1875047349,
#   'name': 'Hope for our youth today',
#   'category': 'Illustration',
#   'main_category': 'Art',
#   'goal': 6700.0,
#   'launched': '2014-07-21 20:03:14',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 13.0},
#  {'ID': 217543389,
#   'name': 'The uKeg Pressurized Growler for Fresh Beer',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'goal': 75000.0,
#   'launched': '2014-10-15 06:34:48',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 1559525.68},
#  {'ID': 1263082934,
#   'name': 'STEAM for Students',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 5000.0,
#   'launched': '2014-08-15 04:46:08',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 25.0},
#  {'ID': 764437823,
#   'name': 'Cold Waters, Warm Hearts: Portraits of Women Who Fly-Fish',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 10000.0,
#   'launched': '2016-05-19 02:48:20',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 586.0},
#  {'ID': 1341393677,
#   'name': 'Sure Set Hook',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 15000.0,
#   'launched': '2014-12-16 15:43:20',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 100.0},
#  {'ID': 1149469807,
#   'name': 'Bespoke by Demian Custom Menswear',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'goal': 10000.0,
#   'launched': '2015-08-11 21:43:39',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'ID': 1968352897,
#   'name': 'Renewable Soy + American Made Candles = LOVE',
#   'category': 'Candles',
#   'main_category': 'Crafts',
#   'goal': 1000.0,
#   'launched': '2012-01-24 02:19:34',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 2325.0},
#  {'ID': 693501911,
#   'name': 'Spray Art on canvas series',
#   'category': 'Painting',
#   'main_category': 'Art',
#   'goal': 5000.0,
#   'launched': '2015-04-14 13:33:36',
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged_real': 0.0},
#  {'ID': 397524601,
#   'name': "Make Rubulad's Dream Home Come True",
#   'category': 'Mixed Media',
#   'main_category': 'Art',
#   'goal': 35000.0,
#   'launched': '2011-11-11 18:49:35',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 37248.52},
#  {'ID': 520797301,
#   'name': 'Bad Habit Beers',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'goal': 25000.0,
#   'launched': '2015-09-17 21:35:33',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 7522.0},
#  {'ID': 1195741430,
#   'name': 'Bring the BBBC home for Christmas (Canceled)',
#   'category': 'Music',
#   'main_category': 'Music',
#   'goal': 55000.0,
#   'launched': '2014-09-25 17:04:11',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 1395.0},
#  {'ID': 2024072867,
#   'name': 'Black Lotus Empire-issue #1',
#   'category': 'Comics',
#   'main_category': 'Comics',
#   'goal': 2500.0,
#   'launched': '2012-08-14 18:25:36',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 3905.51},
#  {'ID': 223758456,
#   'name': 'Toasty the Magic Fireplace',
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'goal': 10000.0,
#   'launched': '2017-09-20 18:04:19',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 33.0},
#  {'ID': 1594750207,
#   'name': 'Lake Forest Drone',
#   'category': 'Photography',
#   'main_category': 'Photography',
#   'goal': 875.0,
#   'launched': '2016-03-05 18:11:17',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 103.0},
#  {'ID': 726485587,
#   'name': 'The Meadow Project',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 20000.0,
#   'launched': '2012-01-07 17:39:58',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 21635.0},
#  {'ID': 260647442,
#   'name': 'Clash in the Caucuses 2016',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'goal': 17500.0,
#   'launched': '2016-10-14 02:44:13',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 682.0},
#  {'ID': 1043191090,
#   'name': 'Politics with Allies',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'goal': 20000.0,
#   'launched': '2017-03-21 18:05:36',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 554.0},
#  {'ID': 395755489,
#   'name': 'Kawaii Heroes Soft Enamel Pins | Stickers | Commissions',
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'goal': 800.0,
#   'launched': '2017-11-03 19:38:21',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 23.0},
#  {'ID': 830800632,
#   'name': 'Martin Game Studios',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 5000.0,
#   'launched': '2014-10-02 18:10:05',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 3.0},
#  {'ID': 2113778157,
#   'name': 'Air Basketball',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 1500.0,
#   'launched': '2013-11-08 03:02:49',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'ID': 163783398,
#   'name': 'ZERUBA',
#   'category': 'Publishing',
#   'main_category': 'Publishing',
#   'goal': 1000.0,
#   'launched': '2015-01-25 02:21:51',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 2.0},
#  {'ID': 2069080555,
#   'name': 'Crashpads and Paddles: A Rock climbing adventure by canoe',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 1500.0,
#   'launched': '2015-05-05 20:37:22',
#   'state': 'canceled',
#   'country': 'CA',
#   'usd_pledged_real': 65.02479070145492},
#  {'ID': 1224888533,
#   'name': 'Eating Up Easter - Finishing Funds',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 30000.0,
#   'launched': '2017-05-10 16:22:26',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 35182.0},
#  {'ID': 1841566953,
#   'name': 'Clocks Cameras Computers & Murder:  What Else Can Go Wrong?',
#   'category': 'Nonfiction',
#   'main_category': 'Publishing',
#   'goal': 6000.0,
#   'launched': '2015-04-19 20:03:18',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 900.0},
#  {'ID': 449615827,
#   'name': 'High Caliber Community (HC2); a place for veteran networking',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'goal': 75000.0,
#   'launched': '2017-11-19 21:37:19',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 4196.0},
#  {'ID': 442102012,
#   'name': "Rudely Stamp'd Historical Impressions",
#   'category': 'Plays',
#   'main_category': 'Theater',
#   'goal': 6000.0,
#   'launched': '2017-10-27 05:04:26',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 550.0},
#  {'ID': 1054276073,
#   'name': '(Teacher) Documentary, Jack teaches Buddhist Monks English',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 2390.0,
#   'launched': '2016-07-28 16:34:56',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 2773.0},
#  {'ID': 1292948737,
#   'name': 'Tarot eCards App: Tarot Reading App for mobile devices',
#   'category': 'Publishing',
#   'main_category': 'Publishing',
#   'goal': 12000.0,
#   'launched': '2013-12-09 13:51:59',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 796.66},
#  {'ID': 2036356057,
#   'name': 'Sound is Revolution',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 50000.0,
#   'launched': '2017-04-23 22:07:56',
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged_real': 14.125019261389902},
#  {'ID': 56346579,
#   'name': 'City of the Shroud',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 14000.0,
#   'launched': '2016-04-06 18:00:04',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 16239.0},
#  {'ID': 797794426,
#   'name': "Skunk Rider's first album",
#   'category': 'Rock',
#   'main_category': 'Music',
#   'goal': 500.0,
#   'launched': '2015-05-01 17:31:59',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 1395.0},
#  {'ID': 1086953170,
#   'name': "'Jamie and Friends' - Greeting Cards",
#   'category': 'Stationery',
#   'main_category': 'Crafts',
#   'goal': 1000.0,
#   'launched': '2015-06-25 18:58:28',
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged_real': 31.15167751783433},
#  {'ID': 955493948,
#   'name': 'W.E.T West End Terminal: Outdoor Chair Show/Art Installation',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'goal': 8500.0,
#   'launched': '2011-05-04 02:51:56',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 8644.0},
#  {'ID': 133917405,
#   'name': 'BrainScrambler',
#   'category': 'Periodicals',
#   'main_category': 'Publishing',
#   'goal': 8000.0,
#   'launched': '2012-04-04 21:26:16',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'ID': 1702541310,
#   'name': 'Paint Ring',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'goal': 55000.0,
#   'launched': '2017-05-15 19:52:07',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 2.0},
#  {'ID': 87518909,
#   'name': 'Just Rock Showcase and Songwriter Circle 2014 at the studio',
#   'category': 'Performance Art',
#   'main_category': 'Art',
#   'goal': 1500.0,
#   'launched': '2013-11-15 17:38:39',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 2180.0},
#  {'ID': 1957326840,
#   'name': 'BRIGADE RETURNS!',
#   'category': 'Comics',
#   'main_category': 'Comics',
#   'goal': 17500.0,
#   'launched': '2013-05-16 21:24:04',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 35343.0},
#  {'ID': 1593966557,
#   'name': 'Red Box Games Dwarves, and Goblins, and Orcs Oh MY!!',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'goal': 5000.0,
#   'launched': '2013-05-19 21:49:38',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 39258.0},
#  {'ID': 1029624752,
#   'name': 'Doodle Art to Color Returns!',
#   'category': 'Art Books',
#   'main_category': 'Publishing',
#   'goal': 25.0,
#   'launched': '2014-06-14 18:50:10',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 25.5},
#  {'ID': 888065158,
#   'name': 'New Patent Design Pocket Sheet+',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 25000.0,
#   'launched': '2015-06-18 23:21:20',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 190.0},
#  {'ID': 14239768,
#   'name': 'What I Did Today',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 5000.0,
#   'launched': '2012-08-16 00:00:27',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 360.0},
#  {'ID': 1890385189,
#   'name': 'The Falling Girl- Chronicles of the Closed World, Book 1',
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'goal': 500.0,
#   'launched': '2012-03-10 01:37:26',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 695.0},
#  {'ID': 368889340,
#   'name': '"Intermittent Polarity" Art book by Brent and Kayla Woodside',
#   'category': 'Illustration',
#   'main_category': 'Art',
#   'goal': 1000.0,
#   'launched': '2012-07-13 03:32:53',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 610.0},
#  {'ID': 671724371,
#   'name': 'The Dark Lord and the Seamstress',
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'goal': 5000.0,
#   'launched': '2014-08-11 21:02:05',
#   'state': 'successful',
#   'country': 'CA',
#   'usd_pledged_real': 4860.630351612315},
#  {'ID': 231038205,
#   'name': "Towering Trees' First Album!",
#   'category': 'Rock',
#   'main_category': 'Music',
#   'goal': 2250.0,
#   'launched': '2013-07-12 21:23:16',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 2267.0},
#  {'ID': 673468258,
#   'name': 'Daybook notebooks (Canceled)',
#   'category': 'Stationery',
#   'main_category': 'Crafts',
#   'goal': 1000.0,
#   'launched': '2016-01-26 06:29:43',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 52.0},
#  {'ID': 765608919,
#   'name': 'Big Barbeque',
#   'category': 'Events',
#   'main_category': 'Food',
#   'goal': 20000.0,
#   'launched': '2014-09-04 15:25:21',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'ID': 1451163055,
#   'name': 'iKlimt App: The Life & Work of Gustav Klimt',
#   'category': 'Digital Art',
#   'main_category': 'Art',
#   'goal': 5000.0,
#   'launched': '2012-01-12 07:17:54',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 66.0},
#  {'ID': 523925424,
#   'name': 'Seasons in the Sanctuary',
#   'category': 'Graphic Design',
#   'main_category': 'Design',
#   'goal': 4000.0,
#   'launched': '2012-09-07 21:56:47',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 4808.0},
#  {'ID': 488491938,
#   'name': 'Charlie Chipmink',
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'goal': 35000.0,
#   'launched': '2017-05-04 02:14:23',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 430.0},
#  {'ID': 899938474,
#   'name': '500 Years Later: An Oral History of Final Fantasy VII',
#   'category': 'Nonfiction',
#   'main_category': 'Publishing',
#   'goal': 38000.0,
#   'launched': '2017-11-10 14:00:05',
#   'state': 'successful',
#   'country': 'GB',
#   'usd_pledged_real': 97495.75267882225},
#  {'ID': 2146928537,
#   'name': 'Crimson Apple, Debut Album "Hello"',
#   'category': 'Music',
#   'main_category': 'Music',
#   'goal': 8000.0,
#   'launched': '2015-07-27 13:53:12',
#   'state': 'undefined',
#   'country': 'N,0"',
#   'usd_pledged_real': 8805.0},
#  {'ID': 870077018,
#   'name': 'Take every shower with Matt Gator and stop shower mat mold',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 34000.0,
#   'launched': '2017-05-10 07:49:12',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 21.0},
#  {'ID': 1564568013,
#   'name': 'The VDown Podcast Intro (Canceled)',
#   'category': 'Rock',
#   'main_category': 'Music',
#   'goal': 1100.0,
#   'launched': '2014-09-03 01:45:25',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'ID': 1010701682,
#   'name': 'XPLUS Watches: Second Release',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 10000.0,
#   'launched': '2015-09-30 00:56:12',
#   'state': 'successful',
#   'country': 'AU',
#   'usd_pledged_real': 11970.37352044794},
#  {'ID': 1425142887,
#   'name': 'Mathatar - An online Maths adventure game for KS2 to GCSE',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 5000.0,
#   'launched': '2016-12-07 18:21:50',
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged_real': 449.34242571846085},
#  {'ID': 1843557102,
#   'name': 'Son of a Gun',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'goal': 20000.0,
#   'launched': '2011-12-28 17:57:05',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'ID': 1721659818,
#   'name': 'Bourbon Chicken',
#   'category': 'Food',
#   'main_category': 'Food',
#   'goal': 30.0,
#   'launched': '2014-07-21 20:36:34',
#   'state': 'failed',
#   'country': 'CA',
#   'usd_pledged_real': 0.0},
#  {'ID': 186346662,
#   'name': 'T-Shirt of the Year',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'goal': 1700.0,
#   'launched': '2011-04-04 06:35:03',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'ID': 619587010,
#   'name': 'Nobody: A Fallout Tale',
#   'category': 'Shorts',
#   'main_category': 'Film & Video',
#   'goal': 8200.0,
#   'launched': '2015-11-10 22:37:04',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1229.0},
#  {'ID': 831196575,
#   'name': 'The Tower',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 50000.0,
#   'launched': '2015-06-22 17:51:49',
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged_real': 439.1273314092417},
#  {'ID': 1517578386,
#   'name': 'AutoDock Car Organizer',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'goal': 50000.0,
#   'launched': '2017-09-01 15:31:27',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1775.0},
#  {'ID': 569529453,
#   'name': 'Let Me Tell You/No Money Down David Pemberton/Sally Phillips',
#   'category': 'Nonfiction',
#   'main_category': 'Publishing',
#   'goal': 10000.0,
#   'launched': '2015-08-31 23:19:47',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'ID': 639226845,
#   'name': 'Kiss Kiss Missiles',
#   'category': 'Performance Art',
#   'main_category': 'Art',
#   'goal': 4000.0,
#   'launched': '2012-02-03 00:35:06',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 4075.0},
#  {'ID': 2072974553,
#   'name': 'The Fountain of Light: a luminous juggling machine',
#   'category': 'Art',
#   'main_category': 'Art',
#   'goal': 8000.0,
#   'launched': '2011-04-03 05:55:28',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 8295.36},
#  {'ID': 328543359,
#   'name': 'Dead of Winter',
#   'category': 'Publishing',
#   'main_category': 'Publishing',
#   'goal': 700.0,
#   'launched': '2017-11-22 18:00:03',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 767.0},
#  {'ID': 893780456,
#   'name': 'To Nowhere From Nobody: An Open Source Music Project',
#   'category': 'Pop',
#   'main_category': 'Music',
#   'goal': 2500.0,
#   'launched': '2012-10-20 15:14:49',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 5.0},
#  {'ID': 1771281327,
#   'name': 'Swiss Producer Battle (Canceled)',
#   'category': 'Music',
#   'main_category': 'Music',
#   'goal': 20000.0,
#   'launched': '2015-07-10 20:55:47',
#   'state': 'canceled',
#   'country': 'CH',
#   'usd_pledged_real': 183.3881751304676},
#  {'ID': 1840068470,
#   'name': 'Diamond by Stay high clothing',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'goal': 2000.0,
#   'launched': '2016-07-11 17:28:19',
#   'state': 'failed',
#   'country': 'AU',
#   'usd_pledged_real': 0.0},
#  {'ID': 933275417,
#   'name': 'Fruition of FORMS OF IDENTIFICATION',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 2000.0,
#   'launched': '2010-10-15 00:16:02',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 2196.0},
#  {'ID': 1612333257,
#   'name': 'CUSTOM PET PORTRAIT IN 3 STYLES ( Cat / Dog / all animals! )',
#   'category': 'Painting',
#   'main_category': 'Art',
#   'goal': 800.0,
#   'launched': '2017-03-15 03:59:16',
#   'state': 'successful',
#   'country': 'HK',
#   'usd_pledged_real': 160.74689437000075},
#  {'ID': 350352717,
#   'name': '"The \'Devil" (Canceled)',
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'goal': 600.0,
#   'launched': '2013-02-07 19:08:20',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 320.0},
#  {'ID': 358910116,
#   'name': 'Piano Wars: Dueling Piano Competition - TV Pilot Episode',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 12500.0,
#   'launched': '2011-04-22 03:01:34',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'ID': 1509749942,
#   'name': 'Clash Calc (Canceled)',
#   'category': 'Games',
#   'main_category': 'Games',
#   'goal': 200.0,
#   'launched': '2015-07-20 19:05:57',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 10.0},
#  {'ID': 256728964,
#   'name': '"Film School Porno" My film school senior project',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 2000.0,
#   'launched': '2010-08-17 00:59:19',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 2038.0},
#  {'ID': 640450615,
#   'name': 'Carry the Tune',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 6000.0,
#   'launched': '2014-03-14 04:43:39',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 6756.0},
#  {'ID': 7168821,
#   'name': 'FitCraft',
#   'category': 'Games',
#   'main_category': 'Games',
#   'goal': 5000.0,
#   'launched': '2015-03-02 23:00:51',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1504.0},
#  {'ID': 727551984,
#   'name': 'Robert Rex Waller Jr "Fancy Free" Solo Covers LP (Pre-Order)',
#   'category': 'Country & Folk',
#   'main_category': 'Music',
#   'goal': 7000.0,
#   'launched': '2016-03-22 18:46:14',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 9244.0},
#  {'ID': 757625439,
#   'name': 'SeaGulls',
#   'category': 'Comedy',
#   'main_category': 'Film & Video',
#   'goal': 8000.0,
#   'launched': '2015-05-02 22:42:38',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 25.0},
#  {'ID': 2012699952,
#   'name': 'iCROS - microscope for your smartphone, tablet or iPod touch',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 20000.0,
#   'launched': '2016-10-18 06:20:52',
#   'state': 'failed',
#   'country': 'CH',
#   'usd_pledged_real': 4235.398579321231},
#  {'ID': 1185745802,
#   'name': 'The Microbrew Project',
#   'category': 'Events',
#   'main_category': 'Food',
#   'goal': 15000.0,
#   'launched': '2014-08-27 18:40:21',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'ID': 1770997012,
#   'name': 'So you want to be an entreprenuer',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'goal': 1000.0,
#   'launched': '2014-10-29 16:23:54',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'ID': 1457582752,
#   'name': 'Zoigl Beer - The New Sheriff in Town (Canceled)',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'goal': 15000.0,
#   'launched': '2015-11-13 05:52:51',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 3681.0},
#  {'ID': 1446627191,
#   'name': 'The Eastern Addition',
#   'category': 'Food',
#   'main_category': 'Food',
#   'goal': 10000.0,
#   'launched': '2012-09-17 05:44:11',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 11204.0},
#  {'ID': 555087193,
#   'name': 'Christian Short Video and Devotional Series',
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'goal': 500.0,
#   'launched': '2012-08-30 04:06:37',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 5.0},
#  {'ID': 2012910935,
#   'name': '"Illuminate" - Artwork Album and Film',
#   'category': 'Mixed Media',
#   'main_category': 'Art',
#   'goal': 30000.0,
#   'launched': '2015-02-05 02:53:40',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 86.0},
#  {'ID': 625077982,
#   'name': 'Bonjour Felicity',
#   'category': 'Shorts',
#   'main_category': 'Film & Video',
#   'goal': 4000.0,
#   'launched': '2010-03-17 07:01:31',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 4139.0},
#  {'ID': 1301695312,
#   'name': 'Edu-tainment game Animals Flipcards',
#   'category': 'Games',
#   'main_category': 'Games',
#   'goal': 1000.0,
#   'launched': '2012-12-21 19:18:50',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 25.0},
#  {'ID': 1262761148,
#   'name': 'Lawsuit - the law is in your hands (Canceled)',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 40000.0,
#   'launched': '2013-09-03 15:01:23',
#   'state': 'canceled',
#   'country': 'GB',
#   'usd_pledged_real': 134.82280431432972},
#  {'ID': 893200716,
#   'name': 'Untitled, fortyseven (47) (Canceled)',
#   'category': 'Painting',
#   'main_category': 'Art',
#   'goal': 50000.0,
#   'launched': '2016-02-29 02:01:17',
#   'state': 'canceled',
#   'country': 'AU',
#   'usd_pledged_real': 8218.89400921659},
#  {'ID': 992643827,
#   'name': '"The Guided"',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 100000.0,
#   'launched': '2013-05-17 16:17:16',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'ID': 344183403,
#   'name': 'Custom gaming arcade cabinets',
#   'category': 'Gaming Hardware',
#   'main_category': 'Games',
#   'goal': 10000.0,
#   'launched': '2016-02-25 23:04:35',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 4.0},
#  {'ID': 776868533,
#   'name': "Tumbling Bones' First Full-Length Album",
#   'category': 'Country & Folk',
#   'main_category': 'Music',
#   'goal': 5000.0,
#   'launched': '2013-11-11 00:58:15',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 7597.0},
#  {'ID': 2071033800,
#   'name': '"Epic Bill Bradley" - A Feature Length Documentary',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 22000.0,
#   'launched': '2013-09-17 16:37:57',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 12765.0},
#  {'ID': 1610502043,
#   'name': 'Two Little Boys',
#   'category': 'Shorts',
#   'main_category': 'Film & Video',
#   'goal': 25000.0,
#   'launched': '2013-04-30 18:47:01',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1235.0},
#  {'ID': 844146888,
#   'name': 'Janadhaar: a film by Jade Ajani and David Meek',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 2000.0,
#   'launched': '2012-02-23 20:37:43',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 2617.26},
#  {'ID': 1849013931,
#   'name': 'Learn Game Development by Building 100 Games.',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 750.0,
#   'launched': '2015-08-05 16:13:40',
#   'state': 'successful',
#   'country': 'CA',
#   'usd_pledged_real': 34988.5923245118},
#  {'ID': 655043686,
#   'name': 'Far from Par is a movie about a man and a talking golf ball.',
#   'category': 'Comedy',
#   'main_category': 'Film & Video',
#   'goal': 200000.0,
#   'launched': '2014-10-06 21:20:06',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 10.0},
#  {'ID': 377028958,
#   'name': '626 Night Market in Southern California',
#   'category': 'Food',
#   'main_category': 'Food',
#   'goal': 9888.0,
#   'launched': '2012-02-27 03:00:12',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 315.0},
#  {'ID': 54530323,
#   'name': 'The Rising: Presented by Harvest Music',
#   'category': 'Music',
#   'main_category': 'Music',
#   'goal': 50000.0,
#   'launched': '2011-05-22 18:07:48',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 100.0},
#  {'ID': 1786294771,
#   'name': 'Scholars',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 2000.0,
#   'launched': '2013-12-19 13:37:07',
#   'state': 'successful',
#   'country': 'GB',
#   'usd_pledged_real': 3389.8862907074326},
#  {'ID': 631148234,
#   'name': 'Prehistoric Clothing & Collectibles - Dinosaur Art & More!',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'goal': 10000.0,
#   'launched': '2016-10-25 02:38:00',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 15247.0},
#  {'ID': 1272797295,
#   'name': 'The Noble Tree Coffee House',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'goal': 2000.0,
#   'launched': '2017-03-22 19:51:54',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 450.0},
#  {'ID': 571737749,
#   'name': 'B-U-T-T-S Limited Edition Screenprinted Shirts!',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'goal': 100.0,
#   'launched': '2016-11-18 08:18:25',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'ID': 1790510065,
#   'name': 'Pass the Cicerone Exams with the Beer Scholar Study Guides',
#   'category': 'Nonfiction',
#   'main_category': 'Publishing',
#   'goal': 2500.0,
#   'launched': '2014-02-12 23:48:55',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 12661.0},
#  {'ID': 1301589086,
#   'name': 'Open Mic p? Baras Backe',
#   'category': 'Experimental',
#   'main_category': 'Theater',
#   'goal': 1500.0,
#   'launched': '2015-09-15 22:44:01',
#   'state': 'successful',
#   'country': 'SE',
#   'usd_pledged_real': 1595.0443831164953},
#  {'ID': 1217223096,
#   'name': 'Please help fund/market a Brand New Quartetto Gelato CD!',
#   'category': 'Classical Music',
#   'main_category': 'Music',
#   'goal': 10000.0,
#   'launched': '2015-03-21 19:48:26',
#   'state': 'failed',
#   'country': 'CA',
#   'usd_pledged_real': 2360.755837940424},
#  {'ID': 1640907259,
#   'name': 'Button-Ups 2.0 | Laces That Click',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 13000.0,
#   'launched': '2017-06-08 15:14:24',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 32960.0},
#  {'ID': 999422958,
#   'name': 'Phaxanation & the Dust Kickers: Our Full Length Record',
#   'category': 'Music',
#   'main_category': 'Music',
#   'goal': 2000.0,
#   'launched': '2010-11-04 21:56:08',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 78.0},
#  {'ID': 1594151490,
#   'name': 'Daniel Boone and the Opening of the American West',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 7500.0,
#   'launched': '2014-01-17 21:05:59',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 50.0},
#  {'ID': 287490383,
#   'name': 'Unexpected Visitors',
#   'category': 'Drama',
#   'main_category': 'Film & Video',
#   'goal': 1400.0,
#   'launched': '2015-12-12 19:09:23',
#   'state': 'successful',
#   'country': 'GB',
#   'usd_pledged_real': 2104.57611139314},
#  {'ID': 1106719420,
#   'name': 'MobilePro: a day in the life of mobile digital professionals',
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'goal': 4000.0,
#   'launched': '2012-08-22 10:11:54',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 352.0},
#  {'ID': 348675857,
#   'name': 'The Decimo leather belt. Guarantee to last 10 years.',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 6000.0,
#   'launched': '2017-08-30 19:52:58',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1159.0},
#  {'ID': 689254247,
#   'name': 'Jenns cakes startup',
#   'category': "Farmer's Markets",
#   'main_category': 'Food',
#   'goal': 500.0,
#   'launched': '2014-07-11 02:56:33',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 26.0},
#  {'ID': 1085163790,
#   'name': 'Ausland Jobs (Canceled)',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'goal': 15000.0,
#   'launched': '2016-06-13 17:02:55',
#   'state': 'canceled',
#   'country': 'AT',
#   'usd_pledged_real': 0.0},
#  {'ID': 689929363,
#   'name': 'On the roof of our house nature',
#   'category': 'Community Gardens',
#   'main_category': 'Food',
#   'goal': 18600.0,
#   'launched': '2016-03-17 08:46:00',
#   'state': 'failed',
#   'country': 'CA',
#   'usd_pledged_real': 0.7852991989948169},
#  {'ID': 866634482,
#   'name': 'A CALL TO ADVENTURE',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 287000.0,
#   'launched': '2012-08-13 23:14:02',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1465.0},
#  {'ID': 1142751603,
#   'name': "Dani's Delectable Mini Donuts",
#   'category': 'Food',
#   'main_category': 'Food',
#   'goal': 50000.0,
#   'launched': '2015-06-22 17:36:58',
#   'state': 'failed',
#   'country': 'CA',
#   'usd_pledged_real': 0.0},
#  {'ID': 1667317146,
#   'name': 'Repossession: A Christmas Album',
#   'category': 'Metal',
#   'main_category': 'Music',
#   'goal': 1750.0,
#   'launched': '2013-12-30 22:58:15',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 125.0},
#  {'ID': 1622591435,
#   'name': 'Exo GP-1 GoPro Housing ï¿½ Make Your GoPro Go Further',
#   'category': 'Camera Equipment',
#   'main_category': 'Technology',
#   'goal': 60000.0,
#   'launched': '2015-09-16 17:54:21',
#   'state': 'failed',
#   'country': 'NZ',
#   'usd_pledged_real': 16682.75440146829},
#  {'ID': 618317766,
#   'name': 'Emergency Cellphone & GPS Handbags by Aubry Lane',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'goal': 10000.0,
#   'launched': '2017-04-04 12:12:43',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 3232.0},
#  {'ID': 1035018498,
#   'name': 'E-Quad. Small Electric Powered Offroad Vehicle',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 9000.0,
#   'launched': '2014-08-28 01:14:48',
#   'state': 'failed',
#   'country': 'NZ',
#   'usd_pledged_real': 493.3260479275624},
#  {'ID': 501846138,
#   'name': 'Illuminate:: A Site Specific Art Installation in Detroit!!!',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'goal': 1500.0,
#   'launched': '2011-05-03 00:07:11',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 1550.0},
#  {'ID': 2109777681,
#   'name': "Point Man: the Vietnam War film Hollywood won't make!",
#   'category': 'Action',
#   'main_category': 'Film & Video',
#   'goal': 16235.0,
#   'launched': '2016-07-14 20:18:54',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'ID': 406930918,
#   'name': 'Googly Eyes For Rocks',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'goal': 20.0,
#   'launched': '2015-02-27 21:28:13',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 57.0},
#  {'ID': 489400918,
#   'name': 'ELLE GREY STORIES',
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'goal': 60000.0,
#   'launched': '2017-06-26 02:25:14',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1144.0},
#  {'ID': 1867100434,
#   'name': "Seattle's new sewing studio!",
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'goal': 3300.0,
#   'launched': '2011-01-06 18:14:34',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 3301.0},
#  {'ID': 73469529,
#   'name': 'Clorofilia Magazine',
#   'category': 'Anthologies',
#   'main_category': 'Comics',
#   'goal': 2000.0,
#   'launched': '2014-10-07 21:29:18',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 2537.0},
#  {'ID': 385170505,
#   'name': 'RockDudeï¿½: musical shooter game with unique soundtrack',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 5000.0,
#   'launched': '2013-07-08 23:44:14',
#   'state': 'canceled',
#   'country': 'GB',
#   'usd_pledged_real': 240.6458624437199},
#  {'ID': 1124458385,
#   'name': 'Jamestown: The First Town In America: The EP',
#   'category': 'Indie Rock',
#   'main_category': 'Music',
#   'goal': 1500.0,
#   'launched': '2012-03-22 02:36:52',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 3128.34},
#  {'ID': 1717487501,
#   'name': 'Beatnik Wear Spring Line Release',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'goal': 1000.0,
#   'launched': '2013-02-06 22:14:25',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 191.0},
#  {'ID': 1301409597,
#   'name': 'Creative Adventures',
#   'category': 'Painting',
#   'main_category': 'Art',
#   'goal': 2000.0,
#   'launched': '2012-11-28 18:01:40',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 2281.0},
#  {'ID': 770920020,
#   'name': 'Ant Dominion',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 30000.0,
#   'launched': '2014-05-20 22:43:37',
#   'state': 'failed',
#   'country': 'CA',
#   'usd_pledged_real': 4985.141158989599},
#  {'ID': 1139928936,
#   'name': 'SocketCircuits -  Build electronic circuits on paper!',
#   'category': 'DIY Electronics',
#   'main_category': 'Technology',
#   'goal': 2000.0,
#   'launched': '2014-09-29 15:58:41',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 6031.0},
#  {'ID': 1748965025,
#   'name': 'Organic elephant garlic farm',
#   'category': 'Farms',
#   'main_category': 'Food',
#   'goal': 150000.0,
#   'launched': '2015-12-10 20:25:22',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'ID': 1204555529,
#   'name': 'ChisanaRobotto Newpop Artbook with a virtual ebook version',
#   'category': 'Mixed Media',
#   'main_category': 'Art',
#   'goal': 47000.0,
#   'launched': '2014-05-16 21:40:13',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 50.0},
#  {'ID': 1313044871,
#   'name': 'Easy to Learn Magic Trick!',
#   'category': 'Woodworking',
#   'main_category': 'Crafts',
#   'goal': 100.0,
#   'launched': '2014-11-14 20:24:24',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 120.0},
#  {'ID': 1397553503,
#   'name': 'Disrupting Debt',
#   'category': 'Publishing',
#   'main_category': 'Publishing',
#   'goal': 8500.0,
#   'launched': '2012-02-06 10:49:38',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 775.0},
#  {'ID': 90056271,
#   'name': 'Breaking Time',
#   'category': 'Comedy',
#   'main_category': 'Film & Video',
#   'goal': 3000.0,
#   'launched': '2017-03-22 17:44:08',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 26.0},
#  {'ID': 953963776,
#   'name': 'An Excel Function that can batch rename, copy, or move files',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'goal': 200.0,
#   'launched': '2015-07-11 04:26:32',
#   'state': 'failed',
#   'country': 'CA',
#   'usd_pledged_real': 36.020846106683024},
#  {'ID': 800793272,
#   'name': 'i+Case //  iPhone 4S and iPhone 4 Bumper / Case iphone4',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 15000.0,
#   'launched': '2011-10-09 21:15:05',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 85371.5},
#  {'ID': 16692614,
#   'name': 'The Indepenent Viewpoint "Be the voice that stands out"',
#   'category': 'Journalism',
#   'main_category': 'Journalism',
#   'goal': 5000.0,
#   'launched': '2015-03-12 20:42:05',
#   'state': 'canceled',
#   'country': 'CA',
#   'usd_pledged_real': 0.0},
#  {'ID': 158538235,
#   'name': 'Intrepid Fools: The Murderous Philanthropist of Croydon Town',
# ...
#   'launched': '2015-04-15 16:15:43',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 1179.0},
#  {'ID': 569385036,
#   'name': 'MaLe Dane: The New ALBUM Debut " Live Fast, Die Pretty"',
#   'category': 'Hip-Hop',
#   'main_category': 'Music',
#   'goal': 10000.0,
#   'launched': '2013-09-27 20:09:12',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 10.0},
#  {'ID': 994264006,
#   'name': 'CARDERATION',
#   'category': 'Playing Cards',
#   'main_category': 'Games',
#   'goal': 5000.0,
#   'launched': '2016-05-03 14:13:14',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 16.0},
#  {'ID': 1486481045,
#   'name': 'Sage Ryza: Toys for Adults',
#   'category': 'Art',
#   'main_category': 'Art',
#   'goal': 3000.0,
#   'launched': '2017-06-30 09:25:47',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'ID': 1426808741,
#   'name': 'Tooo Mini: for Doll? for Human? Fabulous Lab-Grown Diamond',
#   'category': 'Jewelry',
#   'main_category': 'Fashion',
#   'goal': 8000.0,
#   'launched': '2017-03-25 16:52:42',
#   'state': 'successful',
#   'country': 'HK',
#   'usd_pledged_real': 2440.498386287948},
#  {'ID': 1163065900,
#   'name': 'CONFESSIONS!',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'goal': 5000.0,
#   'launched': '2013-05-21 23:36:48',
#   'state': 'successful',
#   'country': 'GB',
#   'usd_pledged_real': 8952.457446479873},
#  {'ID': 893129624,
#   'name': 'Space Cradle - Bring Luxury To Your 3D Mouse Experience',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 2500.0,
#   'launched': '2016-08-10 17:53:53',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 2621.0},
#  {'ID': 172151425,
#   'name': 'Sinbuck by Joe Vigil, David Barbour and Tim Vigil',
#   'category': 'Comics',
#   'main_category': 'Comics',
#   'goal': 2999.0,
#   'launched': '2016-03-05 03:47:08',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 4638.0},
#  {'ID': 494614381,
#   'name': 'Breezy -- Web Series',
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'goal': 5000.0,
#   'launched': '2013-06-21 03:30:12',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 5000.0},
#  {'ID': 1069730226,
#   'name': 'The Keepers web series',
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'goal': 30000.0,
#   'launched': '2013-03-16 04:00:33',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 16669.0},
#  {'ID': 2133213966,
#   'name': 'ipad/tablet stand (Canceled)',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 65000.0,
#   'launched': '2015-05-19 18:24:35',
#   'state': 'canceled',
#   'country': 'CA',
#   'usd_pledged_real': 3239.3447966750873},
#  {'ID': 2087018815,
#   'name': 'Deep Dive DIY',
#   'category': 'Experimental',
#   'main_category': 'Film & Video',
#   'goal': 15000.0,
#   'launched': '2015-03-12 01:32:48',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 110.0},
#  {'ID': 693775889,
#   'name': 'Easy grip dip pen /Calligraphy pen /straight dip pen holder',
#   'category': 'Stationery',
#   'main_category': 'Crafts',
#   'goal': 700.0,
#   'launched': '2017-01-17 20:15:43',
#   'state': 'successful',
#   'country': 'GB',
#   'usd_pledged_real': 1625.0869694861346},
#  {'ID': 928296127,
#   'name': 'BandJam.it -First Video Music Social Network for New Artists',
#   'category': 'Music',
#   'main_category': 'Music',
#   'goal': 25000.0,
#   'launched': '2015-11-23 17:21:15',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 20.0},
#  {'ID': 1084370615,
#   'name': 'Me and the sea around the world',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 8000.0,
#   'launched': '2016-03-06 16:36:44',
#   'state': 'failed',
#   'country': 'FR',
#   'usd_pledged_real': 15.908187034827563},
#  {'ID': 417652056,
#   'name': "Le jeu de l'amour",
#   'category': 'Playing Cards',
#   'main_category': 'Games',
#   'goal': 10000.0,
#   'launched': '2016-02-01 13:35:30',
#   'state': 'failed',
#   'country': 'FR',
#   'usd_pledged_real': 2093.762684345826},
#  {'ID': 1376269167,
#   'name': 'The Mighty Atom',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 10000.0,
#   'launched': '2015-11-03 16:43:01',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 10650.0},
#  {'ID': 1491282171,
#   'name': 'Kilgore Books & Comics 2017 Spring Line',
#   'category': 'Comics',
#   'main_category': 'Comics',
#   'goal': 8000.0,
#   'launched': '2017-05-13 22:20:58',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 10169.0},
#  {'ID': 1467175804,
#   'name': '"Rockin\' Everywhere"',
#   'category': 'Hip-Hop',
#   'main_category': 'Music',
#   'goal': 20000.0,
#   'launched': '2014-06-03 00:04:24',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 15.0},
#  {'ID': 1292148030,
#   'name': 'Andrea Beaton - With Betty and Dave',
#   'category': 'World Music',
#   'main_category': 'Music',
#   'goal': 8000.0,
#   'launched': '2016-03-15 07:03:24',
#   'state': 'successful',
#   'country': 'CA',
#   'usd_pledged_real': 9057.195289799663},
#  {'ID': 1382219843,
#   'name': 'Zipper',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'goal': 10000.0,
#   'launched': '2014-07-29 01:03:31',
#   'state': 'failed',
#   'country': 'CA',
#   'usd_pledged_real': 0.0},
#  {'ID': 1361712743,
#   'name': "A set of 4 bumper stickers to save America's infrastructure",
#   'category': 'Design',
#   'main_category': 'Design',
#   'goal': 140.0,
#   'launched': '2016-01-25 20:50:47',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 96.0},
#  {'ID': 478602668,
#   'name': 'NoHo Fringe Festival performance - #Right2Recess',
#   'category': 'Festivals',
#   'main_category': 'Theater',
#   'goal': 3000.0,
#   'launched': '2017-11-03 20:51:42',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 540.0},
#  {'ID': 189295089,
#   'name': 'A MAN NAMED MAGICK: A Short Documentary About A Professional Magician',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 5000.0,
#   'launched': '2010-09-27 20:51:47',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 5161.0},
#  {'ID': 887319573,
#   'name': 'PhiLOCK (Canceled)',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'goal': 100000.0,
#   'launched': '2015-10-28 13:56:59',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 2532.0},
#  {'ID': 827535157,
#   'name': 'Cravar ï¿½ Leather Tote Bags (Canceled)',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 15000.0,
#   'launched': '2015-10-23 16:33:13',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 6748.0},
#  {'ID': 1169744690,
#   'name': 'Camper Enamel Pin',
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'goal': 350.0,
#   'launched': '2017-09-11 17:57:41',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 379.0},
#  {'ID': 634066630,
#   'name': "Plug 'N Plunge (Bathtub Overflow Pipe Plug)",
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 2500.0,
#   'launched': '2015-02-02 21:15:46',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'ID': 575660043,
#   'name': 'CANCELED (Canceled)',
#   'category': 'Music',
#   'main_category': 'Music',
#   'goal': 33000.0,
#   'launched': '2014-08-10 19:42:03',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 3649.0},
#  {'ID': 2067634614,
#   'name': 'Changing the Radio / Production Industry with an iOS Device',
#   'category': 'Music',
#   'main_category': 'Music',
#   'goal': 500.0,
#   'launched': '2012-11-21 01:18:53',
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged_real': 0.0},
#  {'ID': 1707385269,
#   'name': 'Better Food Control - Less Food Poisoning',
#   'category': 'Food',
#   'main_category': 'Food',
#   'goal': 200000.0,
#   'launched': '2017-02-17 23:25:04',
#   'state': 'failed',
#   'country': 'NO',
#   'usd_pledged_real': 81.55568923233541},
#  {'ID': 1613602272,
#   'name': 'ROPIX JUMP ROPE SHOES',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 10000.0,
#   'launched': '2014-02-05 05:36:38',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 10690.0},
#  {'ID': 1109297992,
#   'name': 'Symphony of 1000: Be a part of it!',
#   'category': 'Classical Music',
#   'main_category': 'Music',
#   'goal': 4000.0,
#   'launched': '2013-12-24 21:40:33',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 162.0},
#  {'ID': 142828580,
#   'name': 'THE POWER PRINCIPLE',
#   'category': 'Comics',
#   'main_category': 'Comics',
#   'goal': 7000.0,
#   'launched': '2012-07-10 12:37:25',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 7263.0},
#  {'ID': 1109543634,
#   'name': "'AlwaysOn' 5pee (for scale)",
#   'category': 'Fine Art',
#   'main_category': 'Photography',
#   'goal': 200.0,
#   'launched': '2014-09-06 01:24:05',
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged_real': 6.327812317086678},
#  {'ID': 1434110341,
#   'name': 'The Prettiest Panties in the World (Canceled)',
#   'category': 'Design',
#   'main_category': 'Design',
#   'goal': 30000.0,
#   'launched': '2015-12-01 18:00:24',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 427.0},
#  {'ID': 48806525,
#   'name': 'Coffee Crisis for the Sega Genesis - Metal, Aliens & Awesome',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 10000.0,
#   'launched': '2016-11-04 21:22:22',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 15076.0},
#  {'ID': 1439048120,
#   'name': 'The Black Operator',
#   'category': 'Comics',
#   'main_category': 'Comics',
#   'goal': 3300.0,
#   'launched': '2013-06-12 03:05:30',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1134.0},
#  {'ID': 1300265365,
#   'name': 'The Athlete Spot: We Have The Ingredients For Your Success',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'goal': 50000.0,
#   'launched': '2017-11-10 03:59:11',
#   'state': 'live',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'ID': 513123115,
#   'name': "Kaila Gieser's debut EP!",
#   'category': 'Music',
#   'main_category': 'Music',
#   'goal': 1500.0,
#   'launched': '2013-04-08 19:15:48',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 25.0},
#  {'ID': 1506474844,
#   'name': "The Revolution's Bride",
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 15000.0,
#   'launched': '2016-06-04 19:59:25',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 10.0},
#  {'ID': 1252795414,
#   'name': 'EZC Smartlight "The Smarter Way To Ride"',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'goal': 400.0,
#   'launched': '2016-03-08 13:26:58',
#   'state': 'successful',
#   'country': 'CA',
#   'usd_pledged_real': 1238.2578992314259},
#  {'ID': 1721170633,
#   'name': 'LINJA shoes - The Finest Comfortable High Heels',
#   'category': 'Footwear',
#   'main_category': 'Fashion',
#   'goal': 25000.0,
#   'launched': '2016-09-06 12:32:38',
#   'state': 'failed',
#   'country': 'NL',
#   'usd_pledged_real': 21766.434162424022},
#  {'ID': 666068495,
#   'name': '360ï¿½ India',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 700.0,
#   'launched': '2015-07-22 11:40:00',
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged_real': 24.826986934798125},
#  {'ID': 1884096172,
#   'name': 'The Wing Commander Orchestral Project Volume 2, Phase 1!',
#   'category': 'Jazz',
#   'main_category': 'Music',
#   'goal': 15000.0,
#   'launched': '2017-07-27 21:58:33',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 16552.0},
#  {'ID': 358516752,
#   'name': 'My YouTube Band Project',
#   'category': 'Music',
#   'main_category': 'Music',
#   'goal': 35000.0,
#   'launched': '2012-06-09 23:58:18',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 79937.33},
#  {'ID': 1658564725,
#   'name': 'Help Fund a \'Miraculous\'  new Musical, "Miracolo"',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'goal': 18000.0,
#   'launched': '2013-09-14 17:41:56',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 18000.0},
#  {'ID': 2071301174,
#   'name': 'Wallets Refined & Redefined - by Obtainium',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 25000.0,
#   'launched': '2012-11-23 14:59:13',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 88867.0},
#  {'ID': 2055734097,
#   'name': 'Powermitten: EPIC performance and Album Mastering (Canceled)',
#   'category': 'Electronic Music',
#   'main_category': 'Music',
#   'goal': 1100.0,
#   'launched': '2011-04-22 08:39:10',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'ID': 252240271,
#   'name': 'Best Man Competition Webseries',
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'goal': 9500.0,
#   'launched': '2013-07-03 20:35:13',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 377.0},
#  {'ID': 12976470,
#   'name': 'Love Collection',
#   'category': 'Painting',
#   'main_category': 'Art',
#   'goal': 5000.0,
#   'launched': '2013-01-29 04:45:19',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'ID': 581166953,
#   'name': 'Pay my rent, dance a jig!',
#   'category': 'Dance',
#   'main_category': 'Dance',
#   'goal': 3000.0,
#   'launched': '2014-07-10 01:19:48',
#   'state': 'failed',
#   'country': 'AU',
#   'usd_pledged_real': 0.9321401938851605},
#  {'ID': 1780435209,
#   'name': 'The Holophonics Record a New Ska Cover Album',
#   'category': 'Rock',
#   'main_category': 'Music',
#   'goal': 2000.0,
#   'launched': '2013-08-29 19:07:17',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 2899.5},
#  {'ID': 2057158348,
#   'name': 'BubblePhoneCaseï¿½, Top anti-hacking phone case system.',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'goal': 10000.0,
#   'launched': '2016-10-31 15:19:14',
#   'state': 'canceled',
#   'country': 'ES',
#   'usd_pledged_real': 368.5088589952062},
#  {'ID': 93529012,
#   'name': 'Hamtramck Labor Day Festival',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'goal': 20000.0,
#   'launched': '2012-06-19 18:04:53',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 2366.0},
#  {'ID': 1551300378,
#   'name': 'Crab Cakes',
#   'category': 'Shorts',
#   'main_category': 'Film & Video',
#   'goal': 3000.0,
#   'launched': '2012-11-02 18:46:42',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 775.0},
#  {'ID': 819881112,
#   'name': 'Excellent "Made in Italy" leather shoes for man/woman',
#   'category': 'Footwear',
#   'main_category': 'Fashion',
#   'goal': 178250.0,
#   'launched': '2016-11-16 18:18:47',
#   'state': 'failed',
#   'country': 'IT',
#   'usd_pledged_real': 799.1225321215919},
#  {'ID': 1776712156,
#   'name': 'Twig the Fairy and the Fairly Short Fairy Tales',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 17000.0,
#   'launched': '2015-11-21 02:06:15',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 25410.0},
#  {'ID': 255401982,
#   'name': 'Civil Architect',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 100000.0,
#   'launched': '2014-11-20 22:00:13',
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged_real': 0.0},
#  {'ID': 750725377,
#   'name': 'GHETTO CHRONICLES The Musical Comedy Stage Play (Canceled)',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'goal': 10000.0,
#   'launched': '2011-07-21 08:13:42',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'ID': 147428325,
#   'name': 'Flyy Magazine',
#   'category': 'Periodicals',
#   'main_category': 'Publishing',
#   'goal': 10000.0,
#   'launched': '2012-01-18 03:55:27',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 20.0},
#  {'ID': 400288569,
#   'name': 'Dracucat : A vampire kitten card game',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'goal': 1900.0,
#   'launched': '2015-09-29 07:04:08',
#   'state': 'successful',
#   'country': 'FR',
#   'usd_pledged_real': 3243.3980764357875},
#  {'ID': 1050943303,
#   'name': "Little Baby's Ice Cream Funds for Responsible Packaging",
#   'category': 'Food',
#   'main_category': 'Food',
#   'goal': 5952.0,
#   'launched': '2012-06-15 06:03:09',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 6314.0},
#  ...]

# %%
collection.insert_many(dictionnaire)

# %%
#collection.delete_many({})

# %% [markdown]
# ## Question 1

# %%
cur=collection.find().sort([("usd_pledged_real",-1)])
list(cur)[0:5]
# Out:
# [{'_id': ObjectId('600381203789f4ca7f33d9d7'),
#   'ID': 342886736,
#   'name': "COOLEST COOLER: 21st Century Cooler that's Actually Cooler",
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 50000.0,
#   'launched': '2014-07-08 10:14:37',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 13285226.36},
#  {'_id': ObjectId('600381203789f4ca7f3434d0'),
#   'ID': 2103598555,
#   'name': 'Pebble 2, Time 2 + All-New Pebble Core',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 1000000.0,
#   'launched': '2016-05-24 15:49:52',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 12779843.49},
#  {'_id': ObjectId('600381203789f4ca7f3469eb'),
#   'ID': 1033978702,
#   'name': 'OUYA: A New Kind of Video Game Console',
#   'category': 'Gaming Hardware',
#   'main_category': 'Games',
#   'goal': 950000.0,
#   'launched': '2012-07-10 14:44:41',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 8596474.58},
#  {'_id': ObjectId('600381203789f4ca7f34e1a2'),
#   'ID': 450099426,
#   'name': 'The Everyday Backpack, Tote, and Sling',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 500000.0,
#   'launched': '2016-07-13 00:47:35',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 6565782.5},
#  {'_id': ObjectId('600381203789f4ca7f346920'),
#   'ID': 1386523707,
#   'name': 'Fidget Cube: A Vinyl Desk Toy',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 15000.0,
#   'launched': '2016-08-30 22:02:09',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 6465690.3}]

# %% [markdown]
# ## Question 2

# %%
nb=collection.find({"state":"successful"}).count()
print(nb)
# Out:
# 53040
# <ipython-input-61-59adb5cc2a38>:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   nb=collection.find({"state":"successful"}).count()

# %% [markdown]
# ## Question 3

# %%
cur = collection.aggregate([{"$group" : {"_id" : "$category", "nombredeprojets" : {"$sum" : 1}}}])
list(cur)
# Out:
# [{'_id': 'Civic Design', 'nombredeprojets': 130},
#  {'_id': '3D Printing', 'nombredeprojets': 271},
#  {'_id': 'Hardware', 'nombredeprojets': 1431},
#  {'_id': 'Music', 'nombredeprojets': 6229},
#  {'_id': 'Drama', 'nombredeprojets': 871},
#  {'_id': 'Apparel', 'nombredeprojets': 2827},
#  {'_id': 'People', 'nombredeprojets': 440},
#  {'_id': 'Fashion', 'nombredeprojets': 3379},
#  {'_id': 'Experimental', 'nombredeprojets': 357},
#  {'_id': 'Small Batch', 'nombredeprojets': 701},
#  {'_id': 'Young Adult', 'nombredeprojets': 328},
#  {'_id': 'Embroidery', 'nombredeprojets': 49},
#  {'_id': 'Webcomics', 'nombredeprojets': 259},
#  {'_id': 'Classical Music', 'nombredeprojets': 1064},
#  {'_id': 'Product Design', 'nombredeprojets': 8886},
#  {'_id': 'Romance', 'nombredeprojets': 74},
#  {'_id': 'R&B', 'nombredeprojets': 172},
#  {'_id': 'Faith', 'nombredeprojets': 439},
#  {'_id': 'Events', 'nombredeprojets': 322},
#  {'_id': 'Gaming Hardware', 'nombredeprojets': 178},
#  {'_id': 'Illustration', 'nombredeprojets': 1263},
#  {'_id': 'Puzzles', 'nombredeprojets': 95},
#  {'_id': 'Video Art', 'nombredeprojets': 65},
#  {'_id': 'Chiptune', 'nombredeprojets': 10},
#  {'_id': 'Rock', 'nombredeprojets': 2707},
#  {'_id': 'Art', 'nombredeprojets': 3358},
#  {'_id': 'Textiles', 'nombredeprojets': 105},
#  {'_id': 'Radio & Podcasts', 'nombredeprojets': 349},
#  {'_id': 'Community Gardens', 'nombredeprojets': 115},
#  {'_id': 'Punk', 'nombredeprojets': 127},
#  {'_id': 'Accessories', 'nombredeprojets': 1204},
#  {'_id': 'Zines', 'nombredeprojets': 144},
#  {'_id': 'Photobooks', 'nombredeprojets': 608},
#  {'_id': 'Literary Journals', 'nombredeprojets': 118},
#  {'_id': 'Places', 'nombredeprojets': 283},
#  {'_id': 'Animation', 'nombredeprojets': 1017},
#  {'_id': 'Technology', 'nombredeprojets': 2690},
#  {'_id': 'Design', 'nombredeprojets': 1641},
#  {'_id': 'Space Exploration', 'nombredeprojets': 137},
#  {'_id': 'Calendars', 'nombredeprojets': 112},
#  {'_id': 'Public Art', 'nombredeprojets': 1248},
#  {'_id': 'DIY Electronics', 'nombredeprojets': 358},
#  {'_id': 'Graphic Design', 'nombredeprojets': 765},
#  {'_id': 'Candles', 'nombredeprojets': 168},
#  {'_id': 'Web', 'nombredeprojets': 2017},
#  {'_id': 'Robots', 'nombredeprojets': 237},
#  {'_id': 'Glass', 'nombredeprojets': 51},
#  {'_id': 'Shorts', 'nombredeprojets': 4857},
#  {'_id': 'Thrillers', 'nombredeprojets': 302},
#  {'_id': 'Bacon', 'nombredeprojets': 78},
#  {'_id': 'Jazz', 'nombredeprojets': 733},
#  {'_id': 'Documentary', 'nombredeprojets': 6498},
#  {'_id': 'Performance Art', 'nombredeprojets': 855},
#  {'_id': 'Drinks', 'nombredeprojets': 995},
#  {'_id': 'Food Trucks', 'nombredeprojets': 687},
#  {'_id': 'Nature', 'nombredeprojets': 219},
#  {'_id': 'Photo', 'nombredeprojets': 58},
#  {'_id': 'Jewelry', 'nombredeprojets': 472},
#  {'_id': 'Printing', 'nombredeprojets': 83},
#  {'_id': 'Dance', 'nombredeprojets': 901},
#  {'_id': 'Country & Folk', 'nombredeprojets': 1790},
#  {'_id': 'Musical', 'nombredeprojets': 367},
#  {'_id': 'Immersive', 'nombredeprojets': 131},
#  {'_id': 'Narrative Film', 'nombredeprojets': 2099},
#  {'_id': 'Pop', 'nombredeprojets': 1302},
#  {'_id': 'Games', 'nombredeprojets': 1331},
#  {'_id': 'Taxidermy', 'nombredeprojets': 7},
#  {'_id': 'Food', 'nombredeprojets': 4612},
#  {'_id': 'Apps', 'nombredeprojets': 2535},
#  {'_id': 'Quilts', 'nombredeprojets': 32},
#  {'_id': 'Translations', 'nombredeprojets': 76},
#  {'_id': 'Blues', 'nombredeprojets': 113},
#  {'_id': 'Comic Books', 'nombredeprojets': 1032},
#  {'_id': 'Television', 'nombredeprojets': 401},
#  {'_id': 'Ceramics', 'nombredeprojets': 128},
#  {'_id': 'Literary Spaces', 'nombredeprojets': 10},
#  {'_id': 'Workshops', 'nombredeprojets': 59},
#  {'_id': 'Live Games', 'nombredeprojets': 394},
#  {'_id': 'Tabletop Games', 'nombredeprojets': 5581},
#  {'_id': 'Audio', 'nombredeprojets': 164},
#  {'_id': 'Restaurants', 'nombredeprojets': 1089},
#  {'_id': 'Pottery', 'nombredeprojets': 40},
#  {'_id': 'Conceptual Art', 'nombredeprojets': 393},
#  {'_id': 'Graphic Novels', 'nombredeprojets': 702},
#  {'_id': 'Mobile Games', 'nombredeprojets': 650},
#  {'_id': 'Knitting', 'nombredeprojets': 78},
#  {'_id': 'Fantasy', 'nombredeprojets': 132},
#  {'_id': 'Photography', 'nombredeprojets': 2239},
#  {'_id': 'Camera Equipment', 'nombredeprojets': 165},
#  {'_id': 'Metal', 'nombredeprojets': 274},
#  {'_id': 'Architecture', 'nombredeprojets': 300},
#  {'_id': 'Poetry', 'nombredeprojets': 532},
#  {'_id': 'Typography', 'nombredeprojets': 44},
#  {'_id': 'Kids', 'nombredeprojets': 109},
#  {'_id': 'Letterpress', 'nombredeprojets': 24},
#  {'_id': 'Performances', 'nombredeprojets': 414},
#  {'_id': 'Indie Rock', 'nombredeprojets': 2192},
#  {'_id': 'Video', 'nombredeprojets': 147},
#  {'_id': 'Mixed Media', 'nombredeprojets': 1118},
#  {'_id': "Children's Books", 'nombredeprojets': 2686},
#  {'_id': 'Interactive Design', 'nombredeprojets': 146},
#  {'_id': 'Action', 'nombredeprojets': 282},
#  {'_id': 'Flight', 'nombredeprojets': 158},
#  {'_id': 'Video Games', 'nombredeprojets': 4799},
#  {'_id': 'Stationery', 'nombredeprojets': 90},
#  {'_id': 'Footwear', 'nombredeprojets': 379},
#  {'_id': 'Animals', 'nombredeprojets': 97},
#  {'_id': 'Weaving', 'nombredeprojets': 38},
#  {'_id': "Farmer's Markets", 'nombredeprojets': 175},
#  {'_id': 'Wearables', 'nombredeprojets': 508},
#  {'_id': 'Sculpture', 'nombredeprojets': 737},
#  {'_id': 'Childrenswear', 'nombredeprojets': 192},
#  {'_id': 'Family', 'nombredeprojets': 130},
#  {'_id': 'Crochet', 'nombredeprojets': 61},
#  {'_id': 'Latin', 'nombredeprojets': 63},
#  {'_id': 'Theater', 'nombredeprojets': 2786},
#  {'_id': 'DIY', 'nombredeprojets': 480},
#  {'_id': 'Webseries', 'nombredeprojets': 2316},
#  {'_id': 'Fabrication Tools', 'nombredeprojets': 96},
#  {'_id': 'Hip-Hop', 'nombredeprojets': 1555},
#  {'_id': 'Print', 'nombredeprojets': 288},
#  {'_id': 'Festivals', 'nombredeprojets': 313},
#  {'_id': 'Couture', 'nombredeprojets': 108},
#  {'_id': 'Electronic Music', 'nombredeprojets': 858},
#  {'_id': 'World Music', 'nombredeprojets': 850},
#  {'_id': 'Fiction', 'nombredeprojets': 3703},
#  {'_id': 'Crafts', 'nombredeprojets': 1834},
#  {'_id': 'Plays', 'nombredeprojets': 539},
#  {'_id': 'Fine Art', 'nombredeprojets': 291},
#  {'_id': 'Spaces', 'nombredeprojets': 331},
#  {'_id': 'Comics', 'nombredeprojets': 1931},
#  {'_id': 'Publishing', 'nombredeprojets': 2332},
#  {'_id': 'Movie Theaters', 'nombredeprojets': 90},
#  {'_id': 'Gadgets', 'nombredeprojets': 1210},
#  {'_id': 'Anthologies', 'nombredeprojets': 300},
#  {'_id': 'Farms', 'nombredeprojets': 482},
#  {'_id': 'Software', 'nombredeprojets': 1194},
#  {'_id': 'Academic', 'nombredeprojets': 367},
#  {'_id': 'Makerspaces', 'nombredeprojets': 91},
#  {'_id': 'Digital Art', 'nombredeprojets': 524},
#  {'_id': 'Periodicals', 'nombredeprojets': 517},
#  {'_id': 'Journalism', 'nombredeprojets': 672},
#  {'_id': 'Painting', 'nombredeprojets': 1288},
#  {'_id': 'Sound', 'nombredeprojets': 255},
#  {'_id': 'Vegan', 'nombredeprojets': 229},
#  {'_id': 'Cookbooks', 'nombredeprojets': 217},
#  {'_id': 'Installations', 'nombredeprojets': 178},
#  {'_id': 'Pet Fashion', 'nombredeprojets': 51},
#  {'_id': 'Film & Video', 'nombredeprojets': 4003},
#  {'_id': 'Ready-to-wear', 'nombredeprojets': 332},
#  {'_id': 'Science Fiction', 'nombredeprojets': 274},
#  {'_id': 'Playing Cards', 'nombredeprojets': 963},
#  {'_id': 'Comedy', 'nombredeprojets': 923},
#  {'_id': 'Horror', 'nombredeprojets': 525},
#  {'_id': 'Residencies', 'nombredeprojets': 32},
#  {'_id': 'Music Videos', 'nombredeprojets': 299},
#  {'_id': 'Art Books', 'nombredeprojets': 1065},
#  {'_id': 'Woodworking', 'nombredeprojets': 433},
#  {'_id': 'Nonfiction', 'nombredeprojets': 3390}]

# %% [markdown]
# ## Question 4

# %%
nbprojets=collection.find({"$and":[{"launched":{"$lt":"2016-01-01"}},{"country":"FR"}]}).count()
print(nbprojets)
# Out:
# 330
# <ipython-input-63-5e1cf5479856>:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   nbprojets = collection.find({"$and":[{"launched":{"$lt":"2016-01-01"}},{"country":"FR"}]}).count()

# %% [markdown]
# ## Question 5

# %%
cur=collection.find({"$and":[{"goal":{"$gt":200000.0}},{"country":"US"}]})
list(cur)
# Out:
# [{'_id': ObjectId('6003811f3789f4ca7f32af55'),
#   'ID': 866634482,
#   'name': 'A CALL TO ADVENTURE',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 287000.0,
#   'launched': '2012-08-13 23:14:02',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1465.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32b008'),
#   'ID': 993194166,
#   'name': 'Storybricks, the storytelling online RPG',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 250000.0,
#   'launched': '2012-05-01 20:49:58',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 23680.54},
#  {'_id': ObjectId('6003811f3789f4ca7f32b010'),
#   'ID': 1147175344,
#   'name': 'Shine On New World',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'goal': 300000.0,
#   'launched': '2013-09-30 18:18:40',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 12314.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32b01f'),
#   'ID': 2012810303,
#   'name': 'Nightclub',
#   'category': 'Music',
#   'main_category': 'Music',
#   'goal': 3000000.0,
#   'launched': '2017-08-11 18:08:07',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32b1a3'),
#   'ID': 593221398,
#   'name': 'Nastaran (Wild Rose)',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 250000.0,
#   'launched': '2015-05-08 21:03:20',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32b1aa'),
#   'ID': 621936552,
#   'name': 'Hubo - Extension Box for iPhone',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'goal': 250000.0,
#   'launched': '2016-10-27 17:43:14',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1996.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32b1c9'),
#   'ID': 1323150226,
#   'name': 'Baja ATV Park (Suspended)',
#   'category': 'Live Games',
#   'main_category': 'Games',
#   'goal': 300000.0,
#   'launched': '2016-04-01 22:04:54',
#   'state': 'suspended',
#   'country': 'US',
#   'usd_pledged_real': 11.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32b1e7'),
#   'ID': 61436443,
#   'name': 'Chihuly Installation for Orlando (Pulse Nightclub)',
#   'category': 'Installations',
#   'main_category': 'Art',
#   'goal': 1000000.0,
#   'launched': '2016-07-13 17:31:26',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 5.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32b2ac'),
#   'ID': 821637012,
#   'name': 'Kurt Vonnegut: Unstuck in Time',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 250000.0,
#   'launched': '2015-02-10 14:05:34',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 300319.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32b2fb'),
#   'ID': 924370408,
#   'name': 'The LAKE HOPPER is a VTOL Flying Water Craft Made in America',
#   'category': 'Flight',
#   'main_category': 'Technology',
#   'goal': 3000000.0,
#   'launched': '2016-11-15 21:06:46',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32b32f'),
#   'ID': 966762561,
#   'name': '"Hill" (11 For 11) (From the writer of Rudy & Hoosiers)',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 1000000.0,
#   'launched': '2012-11-12 23:27:51',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32b356'),
#   'ID': 673847752,
#   'name': 'Saints of The Classroom',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'goal': 250000.0,
#   'launched': '2016-10-19 02:05:16',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 3085.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32b3ee'),
#   'ID': 1751772364,
#   'name': 'Hemingwrite - A Distraction Free Digital Typewriter',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 250000.0,
#   'launched': '2014-12-10 18:58:08',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 342471.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32b431'),
#   'ID': 1529289950,
#   'name': 'Breakfast 24/7',
#   'category': 'Food',
#   'main_category': 'Food',
#   'goal': 1000000.0,
#   'launched': '2016-05-18 00:36:35',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32b45d'),
#   'ID': 314981144,
#   'name': 'FJE REVOLT',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'goal': 500000.0,
#   'launched': '2015-01-14 03:01:52',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32b45e'),
#   'ID': 208383561,
#   'name': 'Austin City Limits 40 Year History Documentary Film',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 400000.0,
#   'launched': '2014-08-29 20:46:59',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 9.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32b4ac'),
#   'ID': 912070501,
#   'name': 'Ozark Mountain Ranch',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 466000.0,
#   'launched': '2015-02-10 19:11:52',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1076.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32b4b7'),
#   'ID': 2116069761,
#   'name': 'STEM Lesson Plan - BotBrainï¿½ Educational Products',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'goal': 279646.0,
#   'launched': '2014-09-04 18:26:25',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 85.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32b4d0'),
#   'ID': 410799527,
#   'name': 'Guitar Godz VR: A 3D Rock Music Game',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 500000.0,
#   'launched': '2017-03-28 19:00:52',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 22612.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32b515'),
#   'ID': 848767036,
#   'name': "The world's first crowd funded millionaire documentary",
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 1000000.0,
#   'launched': '2015-04-24 02:58:26',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 171.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32b57a'),
#   'ID': 1520402606,
#   'name': 'Creating an online game, "Perdition Online".',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 350000.0,
#   'launched': '2013-09-16 22:49:11',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 16.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32b5dc'),
#   'ID': 376621995,
#   'name': 'The Adventures of Billy Buskirk',
#   'category': 'Family',
#   'main_category': 'Film & Video',
#   'goal': 750000.0,
#   'launched': '2017-08-15 19:49:31',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32b6b9'),
#   'ID': 1227415659,
#   'name': 'MY TINSEL TOWN (Canceled)',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'goal': 577000.0,
#   'launched': '2014-07-15 00:55:45',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32b6c4'),
#   'ID': 520101512,
#   'name': 'Moonlight 5 star (Canceled)',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'goal': 250000.0,
#   'launched': '2016-04-19 06:41:47',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32b7be'),
#   'ID': 1256627633,
#   'name': 'Dangerous Seas: A Beautiful Under Water War App (Canceled)',
#   'category': 'Mobile Games',
#   'main_category': 'Games',
#   'goal': 400000.0,
#   'launched': '2016-05-27 17:52:03',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 146.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32b7e7'),
#   'ID': 2033979252,
#   'name': 'ViewCoze.com | Cozy viewing from home (Canceled)',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'goal': 370000.0,
#   'launched': '2015-12-10 23:55:54',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 80.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32b7f4'),
#   'ID': 1751639331,
#   'name': 'Meet kubo: an electric scooter to carry all your stuff!',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'goal': 300000.0,
#   'launched': '2013-11-20 06:00:07',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 56667.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32b81b'),
#   'ID': 1178067412,
#   'name': 'ONEIDNET Social Professional Commercial Corporate Platform',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'goal': 545539.0,
#   'launched': '2017-02-22 19:24:24',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32b88c'),
#   'ID': 499583381,
#   'name': 'The Scariest Movie Ever Created',
#   'category': 'Horror',
#   'main_category': 'Film & Video',
#   'goal': 100000000.0,
#   'launched': '2015-07-23 21:44:02',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32b987'),
#   'ID': 290390319,
#   'name': 'The SEED Project',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 250000.0,
#   'launched': '2012-12-18 23:01:12',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 35.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32b9a1'),
#   'ID': 1560972255,
#   'name': 'NewsRadio Season 6 (Canceled)',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'goal': 3000000.0,
#   'launched': '2015-10-17 00:40:32',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 101.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32b9e7'),
#   'ID': 1876072493,
#   'name': 'Get Me Me Kids (Books, Music, Film & Games)',
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'goal': 500000.0,
#   'launched': '2015-09-10 22:58:39',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32ba67'),
#   'ID': 1517530930,
#   'name': "Daniel's Dream",
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 2000000.0,
#   'launched': '2013-05-22 22:02:09',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 60.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32ba95'),
#   'ID': 658943325,
#   'name': 'iFly Hand Held Camera Crane- pan AND tilt - iPhone GoPro etc',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 444000.0,
#   'launched': '2012-11-05 19:05:56',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 3439.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32bad4'),
#   'ID': 420095150,
#   'name': 'GolferVox',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'goal': 1200000.0,
#   'launched': '2015-06-23 21:12:43',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 70.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32bafb'),
#   'ID': 668413973,
#   'name': 'Power Rangers | fan film reboot movie',
#   'category': 'Action',
#   'main_category': 'Film & Video',
#   'goal': 400000.0,
#   'launched': '2015-12-08 21:34:39',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32bbd0'),
#   'ID': 1481048815,
#   'name': '"Another Network" Film Project',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 225000.0,
#   'launched': '2014-03-31 22:46:31',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 55.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32bc91'),
#   'ID': 1916952451,
#   'name': 'SELF-SUSTAINING ORGANIC FARM',
#   'category': 'Farms',
#   'main_category': 'Food',
#   'goal': 450000.0,
#   'launched': '2014-10-10 17:48:13',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 11.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32bc97'),
#   'ID': 1554575493,
#   'name': 'Fuel-X-Tender',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'goal': 500000.0,
#   'launched': '2014-07-01 04:18:43',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 272.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32bcac'),
#   'ID': 1601085300,
#   'name': 'Salad Barr ( the new fast food restaurant )',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'goal': 270000.0,
#   'launched': '2016-02-26 00:04:18',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32bcb4'),
#   'ID': 1636574067,
#   'name': 'We want your money (Suspended)',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 300000.0,
#   'launched': '2016-06-04 16:51:18',
#   'state': 'suspended',
#   'country': 'US',
#   'usd_pledged_real': 123.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32bd11'),
#   'ID': 773987836,
#   'name': "Dutch's Kegs",
#   'category': 'Small Batch',
#   'main_category': 'Food',
#   'goal': 1000000.0,
#   'launched': '2015-11-17 23:36:06',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 260.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32bd38'),
#   'ID': 1831435950,
#   'name': 'Pro Tailgater Party Plate',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'goal': 365000.0,
#   'launched': '2017-04-25 21:25:17',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 200.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32bd42'),
#   'ID': 178255149,
#   'name': 'Gabriel Device - Free energy for everyone',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'goal': 500000.0,
#   'launched': '2017-11-14 01:35:25',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 81.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32bd7a'),
#   'ID': 1098261281,
#   'name': 'Pallet Wars, Part 1...Two More Weeks and Billions Are Ours!!',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 875000.0,
#   'launched': '2017-10-31 06:35:30',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 5.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32bde2'),
#   'ID': 849179016,
#   'name': 'Fast Easy Lightweight Modular Cabinets PhastPhurniture',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 250000.0,
#   'launched': '2017-03-11 03:10:44',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 710.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32be28'),
#   'ID': 1855118124,
#   'name': 'Sonic Chao World fan game (Canceled)',
#   'category': 'Games',
#   'main_category': 'Games',
#   'goal': 1000000.0,
#   'launched': '2015-01-15 23:33:34',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32bea6'),
#   'ID': 607916149,
#   'name': 'The Darkest Dawn',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 500000.0,
#   'launched': '2013-05-29 04:48:42',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 5.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32bf4d'),
#   'ID': 696960534,
#   'name': 'Adventure Combat Ops - A real life, apocalyptic video game!',
#   'category': 'Live Games',
#   'main_category': 'Games',
#   'goal': 400000.0,
#   'launched': '2014-06-24 01:26:37',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 320.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32bf8b'),
#   'ID': 2053440575,
#   'name': "World's First Smart Football",
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 500000.0,
#   'launched': '2015-04-03 01:17:58',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32bfd2'),
#   'ID': 397353040,
#   'name': 'The Maryanne Godboldo Story (Canceled)',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 250000.0,
#   'launched': '2013-06-20 01:17:50',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 2350.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32bffc'),
#   'ID': 534082236,
#   'name': 'M.A.C.S. (Canceled)',
#   'category': 'Space Exploration',
#   'main_category': 'Technology',
#   'goal': 400000.0,
#   'launched': '2014-10-24 20:53:50',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 8.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32c04e'),
#   'ID': 1957695328,
#   'name': 'Planetary Annihilation - A Next Generation RTS',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 900000.0,
#   'launched': '2012-08-15 21:20:10',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 2229344.36},
#  {'_id': ObjectId('6003811f3789f4ca7f32c050'),
#   'ID': 1618218442,
#   'name': "Pontruff's Pop Shop, Pizza, and Punk Rock",
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'goal': 500000.0,
#   'launched': '2014-07-28 09:05:22',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32c118'),
#   'ID': 1402370273,
#   'name': 'The Good Fight of Faith',
#   'category': 'Family',
#   'main_category': 'Film & Video',
#   'goal': 1000000.0,
#   'launched': '2015-10-20 00:56:49',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32c144'),
#   'ID': 410651072,
#   'name': 'Film Adaptation of "The Traveler"',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 1000000.0,
#   'launched': '2016-10-01 19:42:33',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 25.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32c226'),
#   'ID': 489938719,
#   'name': 'Uncommon Wealth',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 250000.0,
#   'launched': '2013-09-25 18:39:09',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 2110.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32c236'),
#   'ID': 1730464042,
#   'name': 'Design the Starship Enterprise Science Research Mock Up',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 313550.0,
#   'launched': '2013-10-18 09:18:13',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 31.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32c298'),
#   'ID': 1517172285,
#   'name': 'Backyard Soccer Buddy / Football Mate (Overseas)',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'goal': 2000000.0,
#   'launched': '2016-07-20 18:37:09',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32c2e8'),
#   'ID': 1523176093,
#   'name': '"anonymous (street meat)" (Canceled)',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 1000000.0,
#   'launched': '2012-05-18 08:18:34',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32c3ec'),
#   'ID': 934554143,
#   'name': 'Hello Space Boy!',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'goal': 2000000.0,
#   'launched': '2016-06-03 23:59:11',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32c40e'),
#   'ID': 1452500654,
#   'name': 'Interactive Breastfeeding Documentary',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 210000.0,
#   'launched': '2011-08-02 15:54:48',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 12058.3},
#  {'_id': ObjectId('6003811f3789f4ca7f32c41a'),
#   'ID': 1783703627,
#   'name': 'Aquaponics system for supplying fresh organic food.',
#   'category': 'Farms',
#   'main_category': 'Food',
#   'goal': 8000000.0,
#   'launched': '2016-04-06 20:30:05',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 21.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32c46a'),
#   'ID': 1028997654,
#   'name': 'After Reset RPG',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 900000.0,
#   'launched': '2013-11-11 10:41:59',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 47939.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32c4a1'),
#   'ID': 731780695,
#   'name': 'SLAYING GIANTS #GOLIATH',
#   'category': 'Movie Theaters',
#   'main_category': 'Film & Video',
#   'goal': 350000.0,
#   'launched': '2016-07-21 03:42:14',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 2508.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32c4ca'),
#   'ID': 776004598,
#   'name': 'Fan News',
#   'category': 'Journalism',
#   'main_category': 'Journalism',
#   'goal': 275000.0,
#   'launched': '2015-02-17 19:40:55',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 10.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32c4ed'),
#   'ID': 580110957,
#   'name': '*FLASHLIFE* Most Complete Emergency Survival Product Ever.',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'goal': 350000.0,
#   'launched': '2016-09-21 20:21:50',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1865.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32c555'),
#   'ID': 644614031,
#   'name': "Iota: Never lose sight of what's important.",
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 250000.0,
#   'launched': '2014-07-15 08:19:05',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 282155.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32c5c4'),
#   'ID': 281465042,
#   'name': 'RHN - THE REAL HIP-HOP NETWORK TV CHANNEL  DOCUMENTARY',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 2000000.0,
#   'launched': '2014-05-01 20:01:10',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 225.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32c5ce'),
#   'ID': 588787421,
#   'name': 'jfg76tukv u',
#   'category': 'Art',
#   'main_category': 'Art',
#   'goal': 250000.0,
#   'launched': '2015-11-19 16:47:03',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 2.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32c5ec'),
#   'ID': 742934297,
#   'name': 'Shaft in Asia Featured Film',
#   'category': 'Action',
#   'main_category': 'Film & Video',
#   'goal': 1000000.0,
#   'launched': '2015-08-14 22:56:40',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32c616'),
#   'ID': 715019941,
#   'name': 'P.U.R.E. Gamers',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 500000.0,
#   'launched': '2015-08-06 22:22:00',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 25.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32c66e'),
#   'ID': 818541249,
#   'name': 'The Hawaiian Girl Art Studio (Canceled)',
#   'category': 'Digital Art',
#   'main_category': 'Art',
#   'goal': 1100000.0,
#   'launched': '2016-01-26 05:48:05',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32c873'),
#   'ID': 1051776765,
#   'name': 'Independent Broadcasting Company',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'goal': 700000.0,
#   'launched': '2017-04-01 02:34:51',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 56.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32c8d1'),
#   'ID': 595664945,
#   'name': 'Forbidden Woods (Canceled)',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 2300000.0,
#   'launched': '2012-07-19 21:12:51',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32c938'),
#   'ID': 788197692,
#   'name': 'The Guilt Free Life',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'goal': 250000.0,
#   'launched': '2014-06-28 22:05:03',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 20.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32c940'),
#   'ID': 1254965074,
#   'name': 'Mayacama Chocolate-Bean-to-Bar Craft Chocolate, Napa,Ca',
#   'category': 'Small Batch',
#   'main_category': 'Food',
#   'goal': 780000.0,
#   'launched': '2015-02-18 17:23:50',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 267.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32c94e'),
#   'ID': 178418310,
#   'name': 'Puzzle Camp',
#   'category': 'Games',
#   'main_category': 'Games',
#   'goal': 750000.0,
#   'launched': '2014-05-19 03:56:46',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 35.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32c951'),
#   'ID': 1473597203,
#   'name': 'Vehroot Shelf | Use Your Phone or Tablet as Your Car Stereo',
#   'category': 'Sound',
#   'main_category': 'Technology',
#   'goal': 500000.0,
#   'launched': '2017-12-12 18:46:26',
#   'state': 'live',
#   'country': 'US',
#   'usd_pledged_real': 5651.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32c970'),
#   'ID': 715203303,
#   'name': "THE YING YANG MURDER MYSTERY'S (Canceled)",
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'goal': 900000.0,
#   'launched': '2014-12-01 23:50:57',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32c984'),
#   'ID': 374403417,
#   'name': 'Montgomery Al Concert 5FDP and VOLBEAT',
#   'category': 'Rock',
#   'main_category': 'Music',
#   'goal': 1040000.0,
#   'launched': '2014-06-24 02:58:50',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32c98a'),
#   'ID': 1935538858,
#   'name': 'Wall Scaler',
#   'category': 'Flight',
#   'main_category': 'Technology',
#   'goal': 1000000.0,
#   'launched': '2017-03-03 21:30:39',
#   'state': 'suspended',
#   'country': 'US',
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32c9be'),
#   'ID': 1926637288,
#   'name': 'Historic B&B with an in-house French Bakery in Memphis, TN',
#   'category': 'Food',
#   'main_category': 'Food',
#   'goal': 250000.0,
#   'launched': '2016-06-23 01:13:20',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 10100.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32ca17'),
#   'ID': 1715597415,
#   'name': 'Angelz Landing the Movie',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 1200000.0,
#   'launched': '2014-01-13 19:08:09',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 356.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32ca95'),
#   'ID': 779336498,
#   'name': 'Morrison Land',
#   'category': 'Movie Theaters',
#   'main_category': 'Film & Video',
#   'goal': 250000.0,
#   'launched': '2014-05-28 19:42:35',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 10.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32cab0'),
#   'ID': 1934580784,
#   'name': 'Triple Espresso Goes to The Big Apple',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'goal': 300000.0,
#   'launched': '2013-02-09 21:01:57',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 27581.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32cb7c'),
#   'ID': 1596314651,
#   'name': 'Take And Seek the Movie',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 250000.0,
#   'launched': '2013-08-16 04:59:36',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32cb95'),
#   'ID': 1834526569,
#   'name': 'Unsung Story: Tale of the Guardians',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 600000.0,
#   'launched': '2014-01-14 19:03:30',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 660126.51},
#  {'_id': ObjectId('6003811f3789f4ca7f32cc42'),
#   'ID': 2007557271,
#   'name': 'Harishwar Center for Arts, Spirituality & Sustainability',
#   'category': 'Architecture',
#   'main_category': 'Design',
#   'goal': 1800000.0,
#   'launched': '2016-01-04 20:26:57',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 614.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32cc4c'),
#   'ID': 695668947,
#   'name': "The Cancer Patient's Film Project",
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 1500000.0,
#   'launched': '2013-07-12 02:38:19',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 275.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32cc6b'),
#   'ID': 832080779,
#   'name': "Small Change: Kids' Financial Life Skills",
#   'category': 'Software',
#   'main_category': 'Technology',
#   'goal': 250000.0,
#   'launched': '2014-07-17 15:54:12',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 3536.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32cce2'),
#   'ID': 1656648684,
#   'name': 'Save the Williamsburg',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'goal': 40000000.0,
#   'launched': '2015-09-27 15:08:05',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 21700.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32cd28'),
#   'ID': 256448010,
#   'name': 'Nephilim, Nazis and the New World Order',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 500000.0,
#   'launched': '2015-05-13 03:45:32',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32cd38'),
#   'ID': 978588144,
#   'name': 'War At Home',
#   'category': 'Drama',
#   'main_category': 'Film & Video',
#   'goal': 340000.0,
#   'launched': '2015-10-29 16:00:52',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 19328.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32cda7'),
#   'ID': 208391519,
#   'name': 'North East',
#   'category': 'Drama',
#   'main_category': 'Film & Video',
#   'goal': 250000.0,
#   'launched': '2017-05-24 00:17:26',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 2.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32cdc6'),
#   'ID': 1789241689,
#   'name': 'The Great Pyramid, Project USA',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 300000.0,
#   'launched': '2014-06-02 15:53:58',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 35.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32ce03'),
#   'ID': 2126842880,
#   'name': 'Time travel app',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'goal': 375000.0,
#   'launched': '2017-09-12 21:06:34',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 135.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32ce56'),
#   'ID': 1046230768,
#   'name': 'Honolulu Haze (Canceled)',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 500000.0,
#   'launched': '2013-05-08 18:00:16',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 70.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32cef9'),
#   'ID': 2135350794,
#   'name': 'Motor Sports Mailboxes',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'goal': 600000.0,
#   'launched': '2014-11-19 20:20:55',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 200.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32cf8a'),
#   'ID': 381953552,
#   'name': 'Patented MoveNetic Lock - New Post 9-11 Locking Method',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'goal': 350000.0,
#   'launched': '2014-09-03 01:33:36',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 60.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32d0e4'),
#   'ID': 749406436,
#   'name': 'Hoverboard: The Next Evolution in Personal Electric Mobility',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'goal': 500000.0,
#   'launched': '2015-09-17 16:39:03',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 257275.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32d12d'),
#   'ID': 1812682282,
#   'name': 'Make A South African Feature Film! (Canceled)',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 2500000.0,
#   'launched': '2011-12-05 17:22:45',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32d1ce'),
#   'ID': 892520897,
#   'name': 'Feature-Length Movie: Secret of the Missing Grave',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 10000000.0,
#   'launched': '2013-05-03 23:15:16',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 11975.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32d1fd'),
#   'ID': 396599619,
#   'name': "Hey Chicago  It's all about you!",
#   'category': 'Design',
#   'main_category': 'Design',
#   'goal': 380000.0,
#   'launched': '2015-08-17 09:43:37',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 950.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32d23f'),
#   'ID': 2028395602,
#   'name': 'All Points Bulletin (APB): Vendetta',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 300000.0,
#   'launched': '2013-03-27 04:05:39',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 27614.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32d289'),
#   'ID': 233857280,
#   'name': 'As Cine On TV',
#   'category': 'Translations',
#   'main_category': 'Publishing',
#   'goal': 2000000.0,
#   'launched': '2017-03-30 05:36:14',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 192.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32d294'),
#   'ID': 1489384109,
#   'name': 'The Hendrix Keg - Carbonated, Fresh, Craft Beer on Tap',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 300000.0,
#   'launched': '2017-08-16 15:47:26',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 48307.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32d3e8'),
#   'ID': 515152452,
#   'name': 'Love Gives Hope Art Gallery for Cultural Diversity!',
#   'category': 'Art',
#   'main_category': 'Art',
#   'goal': 300000.0,
#   'launched': '2017-08-13 23:22:40',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32d408'),
#   'ID': 549303222,
#   'name': 'The "Get Home Now" Device',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'goal': 250000.0,
#   'launched': '2014-09-30 19:45:59',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32d4d2'),
#   'ID': 599813105,
#   'name': 'In Pursuit of Passion - Travel Television Series',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'goal': 280000.0,
#   'launched': '2016-05-07 00:56:56',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 100.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32d500'),
#   'ID': 1327325648,
#   'name': 'Welcome to the Wonderful World of AIDS',
#   'category': 'Thrillers',
#   'main_category': 'Film & Video',
#   'goal': 500000.0,
#   'launched': '2014-10-27 04:27:59',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 2827.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32d51d'),
#   'ID': 35012487,
#   'name': 'The Homeless art Studio (pic from AP) FUCKING HELP OUT',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'goal': 500000.0,
#   'launched': '2016-01-21 23:34:11',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 116.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32d55b'),
#   'ID': 1109856918,
#   'name': 'From Dawson to Jackson Vineyards',
#   'category': 'Farms',
#   'main_category': 'Food',
#   'goal': 1000000.0,
#   'launched': '2014-09-02 23:28:18',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 25.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32d702'),
#   'ID': 925988701,
#   'name': 'Art Story',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'goal': 350000.0,
#   'launched': '2013-07-07 23:34:52',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 365670.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32d741'),
#   'ID': 918134505,
#   'name': 'My a MAZING Academic Profile',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'goal': 2852666.0,
#   'launched': '2014-07-21 22:13:47',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 130.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32d763'),
#   'ID': 1254826758,
#   'name': 'The Hill (Canceled)',
#   'category': 'Festivals',
#   'main_category': 'Theater',
#   'goal': 1575000.0,
#   'launched': '2014-09-22 22:23:33',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 203.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32d774'),
#   'ID': 12584764,
#   'name': 'Sports Cards Unlimited (Canceled)',
#   'category': 'Playing Cards',
#   'main_category': 'Games',
#   'goal': 400000.0,
#   'launched': '2015-10-16 21:19:00',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32d7cf'),
#   'ID': 222813661,
#   'name': 'Pushup Extreme. (Canceled)',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 215000.0,
#   'launched': '2013-05-22 03:38:02',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 9748.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32d87b'),
#   'ID': 660545998,
#   'name': 'Everyday Dreamers Living in the Beautiful Struggle',
#   'category': 'Hip-Hop',
#   'main_category': 'Music',
#   'goal': 3500000.0,
#   'launched': '2016-12-16 00:59:57',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 11.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32d8a2'),
#   'ID': 1661242136,
#   'name': 'Top Side Dinner Show! Eat, watch, party, and always enjoy!',
#   'category': 'Movie Theaters',
#   'main_category': 'Film & Video',
#   'goal': 425000.0,
#   'launched': '2015-09-13 22:35:58',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32d8ab'),
#   'ID': 263103673,
#   'name': 'The Real Kratos - Epic Action Film',
#   'category': 'Shorts',
#   'main_category': 'Film & Video',
#   'goal': 295000.0,
#   'launched': '2013-07-24 22:59:49',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 251.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32d8b0'),
#   'ID': 842423920,
#   'name': 'My Russian Kitchen: Love Story',
#   'category': 'Food',
#   'main_category': 'Food',
#   'goal': 495000.0,
#   'launched': '2013-09-12 14:45:06',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 150.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32d8d2'),
#   'ID': 34885030,
#   'name': 'The Fuffr Touch Case ï¿½ Multitouch Outside Your Smartphone',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'goal': 250000.0,
#   'launched': '2014-11-19 21:43:41',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 11883.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32d926'),
#   'ID': 335611499,
#   'name': "Joe N'Mo To Go!",
#   'category': 'Food Trucks',
#   'main_category': 'Food',
#   'goal': 400000.0,
#   'launched': '2016-07-04 03:08:12',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 15.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32d957'),
#   'ID': 1368984045,
#   'name': 'Japanese Fighting Fish & Japanese Fighting Fish Hold Em',
#   'category': 'Playing Cards',
#   'main_category': 'Games',
#   'goal': 500000.0,
#   'launched': '2015-01-25 04:36:28',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 10.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32da17'),
#   'ID': 160396578,
#   'name': 'Samurai Lone Wolf',
#   'category': 'Comics',
#   'main_category': 'Comics',
#   'goal': 300000.0,
#   'launched': '2016-02-25 03:05:01',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 3678.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32da25'),
#   'ID': 1794382394,
#   'name': 'Today.Feats.Us = The Human Fund',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'goal': 375000.0,
#   'launched': '2014-07-19 18:42:07',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1079.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32da5f'),
#   'ID': 472277577,
#   'name': 'This is my dream (Este es mi sue?o)',
#   'category': 'Drama',
#   'main_category': 'Film & Video',
#   'goal': 1000000.0,
#   'launched': '2015-08-18 22:45:54',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32da68'),
#   'ID': 25508886,
#   'name': 'Bay Area Snow Park',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 1000000.0,
#   'launched': '2013-11-05 06:31:18',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 26411.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32da8d'),
#   'ID': 514155129,
#   'name': 'A Self-Sufficient Sober Living Farm',
#   'category': 'Farms',
#   'main_category': 'Food',
#   'goal': 600000.0,
#   'launched': '2015-02-06 07:08:13',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 6.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32db00'),
#   'ID': 2139728132,
#   'name': 'ONE DEGREE, a productive social network',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'goal': 1000000.0,
#   'launched': '2015-02-17 18:03:18',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 2.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32db2e'),
#   'ID': 2140393795,
#   'name': 'Art and jewelry made with Silvondï¿½ - Beyond Silver...',
#   'category': 'Mixed Media',
#   'main_category': 'Art',
#   'goal': 201349.0,
#   'launched': '2013-09-10 07:31:39',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 319.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32dc4e'),
#   'ID': 179847507,
#   'name': 'Save the Circus',
#   'category': 'Immersive',
#   'main_category': 'Theater',
#   'goal': 325000.0,
#   'launched': '2017-10-27 19:51:35',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 1332.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32dc81'),
#   'ID': 2145388257,
#   'name': 'Happy Happy, Joy Joy - The Ren and Stimpy Story',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 289400.0,
#   'launched': '2017-07-13 09:04:59',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 125334.62},
#  {'_id': ObjectId('6003811f3789f4ca7f32dd8d'),
#   'ID': 2088386858,
#   'name': 'The God MC',
#   'category': 'Action',
#   'main_category': 'Film & Video',
#   'goal': 5000000.0,
#   'launched': '2017-03-18 01:15:39',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32de5d'),
#   'ID': 945548819,
#   'name': 'Soaring Beyond - A 90 Day Empowering Life Transformation',
#   'category': 'Publishing',
#   'main_category': 'Publishing',
#   'goal': 250000.0,
#   'launched': '2016-04-11 19:20:55',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32de66'),
#   'ID': 903278166,
#   'name': 'Ninja Warz',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 285000.0,
#   'launched': '2012-04-02 21:00:45',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 2041.75},
#  {'_id': ObjectId('6003811f3789f4ca7f32de72'),
#   'ID': 2059220905,
#   'name': 'MOST. BLOOD. EVER.',
#   'category': 'Horror',
#   'main_category': 'Film & Video',
#   'goal': 250000.0,
#   'launched': '2015-03-10 15:57:14',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 150.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32e02d'),
#   'ID': 1407909615,
#   'name': "A GOOD MAN'S DECISION",
#   'category': 'Drama',
#   'main_category': 'Film & Video',
#   'goal': 500000.0,
#   'launched': '2016-07-05 18:34:37',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 345.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32e04a'),
#   'ID': 168667659,
#   'name': 'Happy REX( Kids Book Collection) (Canceled)',
#   'category': 'Publishing',
#   'main_category': 'Publishing',
#   'goal': 300000.0,
#   'launched': '2015-09-20 18:22:21',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32e072'),
#   'ID': 1091660319,
#   'name': 'Hooked on a rail',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 400000.0,
#   'launched': '2014-04-10 18:40:50',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32e11a'),
#   'ID': 177668646,
#   'name': 'The Fantom Messenger',
#   'category': 'Thrillers',
#   'main_category': 'Film & Video',
#   'goal': 500000.0,
#   'launched': '2014-12-15 18:30:30',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32e19e'),
#   'ID': 1303336823,
#   'name': 'Trump Redux: Help us tell the real story about Donald Trump.',
#   'category': 'Web',
#   'main_category': 'Journalism',
#   'goal': 250000.0,
#   'launched': '2016-03-11 00:12:56',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 105.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32e1aa'),
#   'ID': 111219053,
#   'name': 'AIRBLADE:  Extreme Hockey',
#   'category': 'Games',
#   'main_category': 'Games',
#   'goal': 700000.0,
#   'launched': '2014-02-25 15:07:36',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 23332.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32e1d5'),
#   'ID': 815224727,
#   'name': 'Superior Motors: Community Restaurant & Farm Ecosystem',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'goal': 250000.0,
#   'launched': '2013-12-04 18:56:58',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 310225.01},
#  {'_id': ObjectId('6003811f3789f4ca7f32e1f2'),
#   'ID': 641127794,
#   'name': 'Hey Moe! Hey Dad!',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 350000.0,
#   'launched': '2013-11-29 19:20:16',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 13722.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32e254'),
#   'ID': 1776808836,
#   'name': 'Air Dash Online  - A Competitive Platform Fighter (Canceled)',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 355555.0,
#   'launched': '2013-10-11 13:55:39',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 7300.69},
#  {'_id': ObjectId('6003811f3789f4ca7f32e25c'),
#   'ID': 1528207588,
#   'name': 'Get Em Up',
#   'category': 'Music',
#   'main_category': 'Music',
#   'goal': 1000000.0,
#   'launched': '2017-01-26 16:41:24',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32e25e'),
#   'ID': 1085392746,
#   'name': "EDM 2015 Dj's United",
#   'category': 'Electronic Music',
#   'main_category': 'Music',
#   'goal': 700000.0,
#   'launched': '2014-08-18 21:26:14',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32e27f'),
#   'ID': 1649193369,
#   'name': "Moreno's Art (Canceled)",
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'goal': 500000.0,
#   'launched': '2014-05-07 01:48:47',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32e28d'),
#   'ID': 2074230505,
#   'name': 'DEADSKINS (Canceled)',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 365000.0,
#   'launched': '2014-06-10 16:32:34',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 6032.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32e425'),
#   'ID': 1027165866,
#   'name': 'Little Magdeline (Film)',
#   'category': 'Romance',
#   'main_category': 'Film & Video',
#   'goal': 400000.0,
#   'launched': '2014-10-02 23:56:38',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 666.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32e508'),
#   'ID': 1053192629,
#   'name': 'INSIDEOUT (Canceled)',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 1250000.0,
#   'launched': '2014-09-23 20:19:49',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32e543'),
#   'ID': 697445050,
#   'name': 'Remix IO - A 4K, Nougat-powered, All-in-One device',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 250000.0,
#   'launched': '2016-10-20 16:57:37',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 598268.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32e54f'),
#   'ID': 657975875,
#   'name': 'KaliPAK is a portable, renewable energy generator',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'goal': 250000.0,
#   'launched': '2014-10-31 20:20:15',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 135679.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32e574'),
#   'ID': 302169659,
#   'name': 'Chips Challenge Ultimate 3D',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 300000.0,
#   'launched': '2015-10-30 17:55:46',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 80.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32e643'),
#   'ID': 873901225,
#   'name': 'STD-Verify: An online STD verification website.',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'goal': 500000.0,
#   'launched': '2016-07-28 18:38:15',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 26.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32e7a3'),
#   'ID': 890740934,
#   'name': "John Knight's Operation: Project A.L.B.A (Canceled)",
#   'category': 'Comics',
#   'main_category': 'Comics',
#   'goal': 225000.0,
#   'launched': '2012-05-23 01:36:10',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 40.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32e7da'),
#   'ID': 1684160843,
#   'name': 'Throwing an art event In Petersburg VA',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'goal': 313400.0,
#   'launched': '2016-08-17 10:09:58',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32e835'),
#   'ID': 832406968,
#   'name': 'Designed snare drum heads (Canceled)',
#   'category': 'Illustration',
#   'main_category': 'Art',
#   'goal': 1000000.0,
# ...
#   'category': 'Shorts',
#   'main_category': 'Film & Video',
#   'goal': 300000.0,
#   'launched': '2013-07-30 00:27:10',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 10.0},
#  {'_id': ObjectId('600381203789f4ca7f33deee'),
#   'ID': 395860704,
#   'name': 'The Tasty Tea Project',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'goal': 225000.0,
#   'launched': '2016-10-29 16:15:48',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 39.0},
#  {'_id': ObjectId('600381203789f4ca7f33df3e'),
#   'ID': 974997366,
#   'name': 'TRONICA EVOLUTION. Blogger. Superhero. Mother.',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 20000000.0,
#   'launched': '2010-09-06 07:12:12',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f33df4d'),
#   'ID': 1797412217,
#   'name': 'Help save our environment',
#   'category': 'Fabrication Tools',
#   'main_category': 'Technology',
#   'goal': 750000.0,
#   'launched': '2016-06-19 19:14:48',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f33dfe9'),
#   'ID': 729227318,
#   'name': 'G?te Backpackers Hostel in Leavenworth, Washington',
#   'category': 'Architecture',
#   'main_category': 'Design',
#   'goal': 399000.0,
#   'launched': '2017-05-31 07:58:34',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 5835.0},
#  {'_id': ObjectId('600381203789f4ca7f33e02a'),
#   'ID': 1935120990,
#   'name': 'The Chainsaw Incident (Canceled)',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 275000.0,
#   'launched': '2014-04-30 19:13:19',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 24784.0},
#  {'_id': ObjectId('600381203789f4ca7f33e02f'),
#   'ID': 554106997,
#   'name': 'The EarClips',
#   'category': 'Mixed Media',
#   'main_category': 'Art',
#   'goal': 500000.0,
#   'launched': '2014-03-19 18:30:17',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 25.0},
#  {'_id': ObjectId('600381203789f4ca7f33e100'),
#   'ID': 728255059,
#   'name': 'The Risen (Canceled)',
#   'category': 'Horror',
#   'main_category': 'Film & Video',
#   'goal': 450000.0,
#   'launched': '2016-05-18 00:07:32',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f33e1ac'),
#   'ID': 1180591140,
#   'name': 'Blossom Cafe & Lounge',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'goal': 500000.0,
#   'launched': '2015-03-04 18:42:18',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 110.0},
#  {'_id': ObjectId('600381203789f4ca7f33e1c2'),
#   'ID': 1106311407,
#   'name': 'Missionary Men',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 2400000.0,
#   'launched': '2013-11-02 15:01:30',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 27310.0},
#  {'_id': ObjectId('600381203789f4ca7f33e1e3'),
#   'ID': 1045401555,
#   'name': '"Dreamin\' of You" needs support with funding. Love is Love!',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 300000.0,
#   'launched': '2012-05-17 02:08:34',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 100.0},
#  {'_id': ObjectId('600381203789f4ca7f33e251'),
#   'ID': 1201877330,
#   'name': 'The Orgonite Pyramid 5 Stories tall !!!',
#   'category': 'Architecture',
#   'main_category': 'Design',
#   'goal': 577000.0,
#   'launched': '2014-07-29 14:43:44',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 25.0},
#  {'_id': ObjectId('600381203789f4ca7f33e263'),
#   'ID': 1563693638,
#   'name': 'Mobile 3D Printing Education Command Unit',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 430000.0,
#   'launched': '2015-03-12 19:59:35',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f33e27b'),
#   'ID': 377004200,
#   'name': 'Uooja',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'goal': 300000.0,
#   'launched': '2015-07-24 04:49:49',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 60.0},
#  {'_id': ObjectId('600381203789f4ca7f33e2a2'),
#   'ID': 288461362,
#   'name': 'Presst. The Magazine of You. (Canceled)',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'goal': 250000.0,
#   'launched': '2016-03-28 17:30:36',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 2500.0},
#  {'_id': ObjectId('600381203789f4ca7f33e346'),
#   'ID': 2091396529,
#   'name': 'Bistraung Brewing Company',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'goal': 2400000.0,
#   'launched': '2015-10-12 23:58:26',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f33e360'),
#   'ID': 511118298,
#   'name': 'MelloShip',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 350000.0,
#   'launched': '2016-09-19 21:08:37',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1492.0},
#  {'_id': ObjectId('600381203789f4ca7f33e3ab'),
#   'ID': 1252853381,
#   'name': 'Muv-Luv: A Pretty Sweet Visual Novel Series',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 250000.0,
#   'launched': '2015-09-24 20:54:25',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 1255444.0},
#  {'_id': ObjectId('600381203789f4ca7f33e4f9'),
#   'ID': 1593659820,
#   'name': 'MINED IN DETROIT! BBQ/BROIL NaCl (Salt) Block. THE D@ 801ï¿½C.',
#   'category': 'Food',
#   'main_category': 'Food',
#   'goal': 777777.0,
#   'launched': '2015-11-25 00:43:55',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f33e514'),
#   'ID': 2120153871,
#   'name': 'Kasimono (Canceled)',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 550000.0,
#   'launched': '2012-10-17 20:23:23',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 20793.0},
#  {'_id': ObjectId('600381203789f4ca7f33e5f0'),
#   'ID': 184465225,
#   'name': 'EL extraterrestrial life',
#   'category': 'Science Fiction',
#   'main_category': 'Film & Video',
#   'goal': 500000.0,
#   'launched': '2015-03-31 01:39:55',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f33e608'),
#   'ID': 666676350,
#   'name': '223 Brush Street',
#   'category': 'Plays',
#   'main_category': 'Theater',
#   'goal': 5000000.0,
#   'launched': '2016-03-24 17:34:35',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('600381203789f4ca7f33e67c'),
#   'ID': 1240992350,
#   'name': 'The refuge.',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 350000.0,
#   'launched': '2015-09-25 16:33:50',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 10.0},
#  {'_id': ObjectId('600381203789f4ca7f33e6f5'),
#   'ID': 783490068,
#   'name': '"RESTORING FREEDOM"',
#   'category': 'Nonfiction',
#   'main_category': 'Publishing',
#   'goal': 1500000.0,
#   'launched': '2015-12-03 00:05:28',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 3.0},
#  {'_id': ObjectId('600381203789f4ca7f33e717'),
#   'ID': 1086775799,
#   'name': 'Rise Of The Martians - Destroy All Humans',
#   'category': 'Science Fiction',
#   'main_category': 'Film & Video',
#   'goal': 500000.0,
#   'launched': '2014-10-06 21:33:58',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 51.0},
#  {'_id': ObjectId('600381203789f4ca7f33e721'),
#   'ID': 1859575272,
#   'name': 'Multifamily Apartment development',
#   'category': 'Woodworking',
#   'main_category': 'Crafts',
#   'goal': 1200000.0,
#   'launched': '2016-07-20 03:08:05',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f33e771'),
#   'ID': 1356175125,
#   'name': 'Power Knot Save the planet, NO food waste to the landfill',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'goal': 250000.0,
#   'launched': '2015-03-14 02:11:38',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f33e8f3'),
#   'ID': 1413335650,
#   'name': 'Fish Bonez...Fresh Seafood Grill',
#   'category': 'Food',
#   'main_category': 'Food',
#   'goal': 250000.0,
#   'launched': '2012-09-17 21:33:22',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 125.0},
#  {'_id': ObjectId('600381203789f4ca7f33e96a'),
#   'ID': 172516885,
#   'name': 'The Ultimate Sacrifice: Depicted in Sculptural Glass & Light',
#   'category': 'Sculpture',
#   'main_category': 'Art',
#   'goal': 850000.0,
#   'launched': '2015-03-17 16:25:08',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 1257.0},
#  {'_id': ObjectId('600381203789f4ca7f33e9da'),
#   'ID': 1586943977,
#   'name': 'The Directorate',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 235000.0,
#   'launched': '2012-09-05 23:36:39',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 11285.27},
#  {'_id': ObjectId('600381203789f4ca7f33e9f1'),
#   'ID': 1861707770,
#   'name': 'Believers',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 10000000.0,
#   'launched': '2013-08-23 16:57:54',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 100.0},
#  {'_id': ObjectId('600381203789f4ca7f33ea3d'),
#   'ID': 617735693,
#   'name': 'SOAK: An Ecological Urban Bathhouse',
#   'category': 'Design',
#   'main_category': 'Design',
#   'goal': 240000.0,
#   'launched': '2013-11-26 06:25:19',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 26508.0},
#  {'_id': ObjectId('600381203789f4ca7f33ea3f'),
#   'ID': 1401115858,
#   'name': '"THAT WHICH LURKS" a Japanese horror graphic novel.',
#   'category': 'Graphic Novels',
#   'main_category': 'Comics',
#   'goal': 800000.0,
#   'launched': '2017-01-11 22:35:10',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 820.0},
#  {'_id': ObjectId('600381203789f4ca7f33ea72'),
#   'ID': 607788518,
#   'name': 'Night of the Demons: After-Party',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 225000.0,
#   'launched': '2013-06-17 17:06:48',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 5612.66},
#  {'_id': ObjectId('600381203789f4ca7f33eb6e'),
#   'ID': 611155791,
#   'name': 'Deadlands III: The New World (Canceled)',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'goal': 1000000.0,
#   'launched': '2010-07-28 21:54:36',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 4462.0},
#  {'_id': ObjectId('600381203789f4ca7f33eba1'),
#   'ID': 235391610,
#   'name': 'ANNIHILATOR is a NO holds bar super car built 4 21st century',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 1000000.0,
#   'launched': '2015-03-26 08:30:58',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1085.0},
#  {'_id': ObjectId('600381203789f4ca7f33eba3'),
#   'ID': 777796215,
#   'name': "JP's Fully Automated Burger Machine",
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'goal': 350000.0,
#   'launched': '2016-09-28 22:58:32',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 181.0},
#  {'_id': ObjectId('600381203789f4ca7f33ebc9'),
#   'ID': 2133507572,
#   'name': 'Unfinished Furniture',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 300000.0,
#   'launched': '2013-04-25 22:44:49',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f33ebdc'),
#   'ID': 28326293,
#   'name': 'Untitled Taraji P. Henson and Michael Ealy',
#   'category': 'Drama',
#   'main_category': 'Film & Video',
#   'goal': 300000.0,
#   'launched': '2017-07-18 03:50:29',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f33ecb4'),
#   'ID': 439416501,
#   'name': 'ANTIDOTE',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 300000.0,
#   'launched': '2012-06-18 21:16:42',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f33ed0d'),
#   'ID': 493623060,
#   'name': 'Legend Of The Keepers',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 450000.0,
#   'launched': '2015-12-14 15:53:06',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 14.0},
#  {'_id': ObjectId('600381203789f4ca7f33ed1f'),
#   'ID': 1845730356,
#   'name': 'Agora (Canceled)',
#   'category': 'Spaces',
#   'main_category': 'Food',
#   'goal': 300000.0,
#   'launched': '2016-01-11 19:33:54',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 7200.0},
#  {'_id': ObjectId('600381203789f4ca7f33ed5c'),
#   'ID': 1377112614,
#   'name': 'Just Fellowship',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 250000.0,
#   'launched': '2014-11-22 16:49:36',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 80.0},
#  {'_id': ObjectId('600381203789f4ca7f33ed65'),
#   'ID': 1407711307,
#   'name': 'An Everyday Gift To Our Veterans.',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'goal': 430000.0,
#   'launched': '2016-03-18 15:08:05',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 50.0},
#  {'_id': ObjectId('600381203789f4ca7f33ed90'),
#   'ID': 1055272393,
#   'name': 'Rover Blowerï¿½ (Canceled)',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 250000.0,
#   'launched': '2014-04-19 16:39:16',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f33edef'),
#   'ID': 1476292196,
#   'name': 'Infameous',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 259000.0,
#   'launched': '2013-07-03 18:13:36',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('600381203789f4ca7f33ee40'),
#   'ID': 1351667354,
#   'name': 'Orderfoood Technologies',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'goal': 1000000.0,
#   'launched': '2017-08-08 23:54:15',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 15.0},
#  {'_id': ObjectId('600381203789f4ca7f33ee4d'),
#   'ID': 1979330873,
#   'name': 'Axis Game Factory - dream, build, create and play!',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 400000.0,
#   'launched': '2013-01-02 18:09:12',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 25209.0},
#  {'_id': ObjectId('600381203789f4ca7f33ef2a'),
#   'ID': 1602722212,
#   'name': 'Mount Grace Monastery Replica',
#   'category': 'Architecture',
#   'main_category': 'Design',
#   'goal': 16250000.0,
#   'launched': '2015-03-13 16:57:27',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f33ef8c'),
#   'ID': 723636757,
#   'name': 'World Domination: Gamers cafe and Lounge',
#   'category': 'Spaces',
#   'main_category': 'Food',
#   'goal': 500000.0,
#   'launched': '2015-03-11 20:09:20',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f33f031'),
#   'ID': 626473194,
#   'name': 'Festival of Magic - Wii U/PC/Mac/Linux/Steam (Canceled)',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 250000.0,
#   'launched': '2013-11-21 00:18:19',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 49286.55},
#  {'_id': ObjectId('600381203789f4ca7f33f075'),
#   'ID': 2123518228,
#   'name': 'On Demand Delivery and Transportation Services!',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'goal': 500000.0,
#   'launched': '2015-01-16 23:36:34',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 226.0},
#  {'_id': ObjectId('600381203789f4ca7f33f09b'),
#   'ID': 5190029,
#   'name': "The Patrick Kyle Children's Museum",
#   'category': 'Art',
#   'main_category': 'Art',
#   'goal': 2000000.0,
#   'launched': '2015-06-26 20:16:29',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f33f0ca'),
#   'ID': 1891106526,
#   'name': 'Class of Heroes 2 Deluxe for the PSPï¿½ system',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 500000.0,
#   'launched': '2012-03-28 08:59:58',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 96951.01},
#  ...]

# %% [markdown]
# ## Question 6

# %%
collection.create_index([("name",  "text")])
# Out:
# 'name_text'

# %%
collection.index_information()
# Out:
# {'_id_': {'v': 2, 'key': [('_id', 1)]},
#  'name_text': {'v': 2,
#   'key': [('_fts', 'text'), ('_ftsx', 1)],
#   'weights': SON([('name', 1)]),
#   'default_language': 'english',
#   'language_override': 'language',
#   'textIndexVersion': 3}}

# %%
cur=collection.find({"$text":{ "$search": "sport"}})
list(cur)
# Out:
# [{'_id': ObjectId('6003811f3789f4ca7f335e08'),
#   'ID': 1875366029,
#   'name': 'Sport Smart. A New Genre of Sports TV. Sport Fans Unite!!!',
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'goal': 4500.0,
#   'launched': '2010-12-16 08:40:02',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 25.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32dfea'),
#   'ID': 1126822169,
#   'name': 'Frey Sports App - We connect sports people.',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'goal': 25000.0,
#   'launched': '2016-12-12 11:30:28',
#   'state': 'failed',
#   'country': 'DK',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f34c668'),
#   'ID': 1081541783,
#   'name': 'Daily Fantasy Sports | Sports Analytics Platform | DFS',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'goal': 33750.0,
#   'launched': '2017-11-12 14:48:42',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f338f06'),
#   'ID': 377805062,
#   'name': 'Intro To: Sports Tech and THE Sports Techie Online Community',
#   'category': 'Journalism',
#   'main_category': 'Journalism',
#   'goal': 8000.0,
#   'launched': '2016-09-07 01:32:35',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 725.0},
#  {'_id': ObjectId('6003811f3789f4ca7f3361e2'),
#   'ID': 96596569,
#   'name': 'A New Sport Show For The New Generation of Sports Fans!',
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'goal': 3000.0,
#   'launched': '2014-02-13 23:18:14',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 30.0},
#  {'_id': ObjectId('6003811f3789f4ca7f332f62'),
#   'ID': 2072875895,
#   'name': 'Odds Hacker - Sports Betting and Fantasy Sports Predictions',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'goal': 60000.0,
#   'launched': '2015-09-15 15:45:34',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 16000.0},
#  {'_id': ObjectId('6003811f3789f4ca7f33125c'),
#   'ID': 2105052828,
#   'name': 'Elite-Sports-Worldwide- presents all around sports socks!',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'goal': 10000.0,
#   'launched': '2012-06-22 17:52:06',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 100.0},
#  {'_id': ObjectId('600381203789f4ca7f343a8f'),
#   'ID': 1242518665,
#   'name': 'sport to go: Le sport partout et sans engagement!',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'goal': 10000.0,
#   'launched': '2017-04-29 17:54:52',
#   'state': 'failed',
#   'country': 'FR',
#   'usd_pledged_real': 515.9842961301179},
#  {'_id': ObjectId('600381203789f4ca7f34ea35'),
#   'ID': 1547684157,
#   'name': 'S2SA - Sport to Strap Adapter for Samsung Gear S2 Sport (3G)',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'goal': 2700.0,
#   'launched': '2016-01-22 23:36:37',
#   'state': 'failed',
#   'country': 'AT',
#   'usd_pledged_real': 1000.4402377283734},
#  {'_id': ObjectId('600381203789f4ca7f33dbcf'),
#   'ID': 1642678550,
#   'name': "Sports Liberated l Free women's sport lifestyle magazine app",
#   'category': 'Journalism',
#   'main_category': 'Journalism',
#   'goal': 12000.0,
#   'launched': '2015-06-12 23:08:16',
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged_real': 3025.1524271390476},
#  {'_id': ObjectId('6003811f3789f4ca7f335791'),
#   'ID': 1500242962,
#   'name': 'Zumer Sport:Lunch Boxes Made From Actual Sport Ball Material',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 15000.0,
#   'launched': '2014-11-13 22:45:35',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 456.0},
#  {'_id': ObjectId('600381203789f4ca7f34efef'),
#   'ID': 33929889,
#   'name': 'Sports podcast',
#   'category': 'Audio',
#   'main_category': 'Journalism',
#   'goal': 250.0,
#   'launched': '2017-07-06 01:11:27',
#   'state': 'failed',
#   'country': 'CA',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f34d400'),
#   'ID': 1078281579,
#   'name': 'Skyline Sports',
#   'category': 'Painting',
#   'main_category': 'Art',
#   'goal': 2000.0,
#   'launched': '2016-11-17 14:32:43',
#   'state': 'failed',
#   'country': 'CA',
#   'usd_pledged_real': 210.21476815663655},
#  {'_id': ObjectId('600381203789f4ca7f348c6f'),
#   'ID': 686496341,
#   'name': 'Sports Court',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'goal': 12500.0,
#   'launched': '2016-05-17 21:55:08',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 5.0},
#  {'_id': ObjectId('600381203789f4ca7f346a08'),
#   'ID': 1572424984,
#   'name': 'Sport Contender',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'goal': 20000.0,
#   'launched': '2017-03-02 03:50:29',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f344f04'),
#   'ID': 187961793,
#   'name': 'The Sport of Photography',
#   'category': 'Photography',
#   'main_category': 'Photography',
#   'goal': 6000.0,
#   'launched': '2012-03-09 03:03:27',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f3412f2'),
#   'ID': 1003561048,
#   'name': 'Sports And The City',
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'goal': 10000.0,
#   'launched': '2012-08-13 20:00:27',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 2350.0},
#  {'_id': ObjectId('600381203789f4ca7f33f243'),
#   'ID': 1890047804,
#   'name': 'Sports Stream',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'goal': 67500.0,
#   'launched': '2015-02-27 21:30:55',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f334ea5'),
#   'ID': 110209153,
#   'name': 'Universal sports',
#   'category': 'Mobile Games',
#   'main_category': 'Games',
#   'goal': 20000.0,
#   'launched': '2017-03-03 02:10:29',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f333a21'),
#   'ID': 861051774,
#   'name': 'Utility Sports',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 9999.0,
#   'launched': '2014-10-20 13:14:51',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f330b5c'),
#   'ID': 1901105792,
#   'name': 'Sports Emblems',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'goal': 10000.0,
#   'launched': '2014-11-10 22:51:40',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 6.0},
#  {'_id': ObjectId('600381203789f4ca7f34f542'),
#   'ID': 1224314059,
#   'name': 'Fantasy Fan Sports',
#   'category': 'Web',
#   'main_category': 'Journalism',
#   'goal': 10000.0,
#   'launched': '2015-09-26 21:21:36',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('600381203789f4ca7f34e0c0'),
#   'ID': 1710166877,
#   'name': 'Sausage Sports Club',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 15000.0,
#   'launched': '2016-08-08 17:36:29',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 15883.77},
#  {'_id': ObjectId('600381203789f4ca7f34d473'),
#   'ID': 411567167,
#   'name': 'Sports Art History',
#   'category': 'Painting',
#   'main_category': 'Art',
#   'goal': 15265.0,
#   'launched': '2016-11-23 13:45:14',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f34b9df'),
#   'ID': 1935410492,
#   'name': 'Bazadee Sports (Canceled)',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'goal': 2000000.0,
#   'launched': '2015-04-06 01:48:58',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 10.0},
#  {'_id': ObjectId('600381203789f4ca7f34b1e0'),
#   'ID': 872034828,
#   'name': 'The Ute Sports Report',
#   'category': 'Radio & Podcasts',
#   'main_category': 'Publishing',
#   'goal': 5000.0,
#   'launched': '2013-06-19 21:49:49',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1355.0},
#  {'_id': ObjectId('600381203789f4ca7f34a74f'),
#   'ID': 1014272616,
#   'name': 'Sports in slow motion',
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'goal': 6000.0,
#   'launched': '2013-10-17 23:36:01',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 861.0},
#  {'_id': ObjectId('600381203789f4ca7f34a47c'),
#   'ID': 1540739778,
#   'name': 'Sports Trivia App',
#   'category': 'Mobile Games',
#   'main_category': 'Games',
#   'goal': 3000.0,
#   'launched': '2017-09-17 16:42:55',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('600381203789f4ca7f349b27'),
#   'ID': 1119839910,
#   'name': 'Kovo Sports Backpack',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 26000.0,
#   'launched': '2014-08-06 04:36:09',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 5082.0},
#  {'_id': ObjectId('600381203789f4ca7f349930'),
#   'ID': 1793033371,
#   'name': 'Waveblade Sports Roller',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 39984.0,
#   'launched': '2016-10-20 08:06:24',
#   'state': 'successful',
#   'country': 'AU',
#   'usd_pledged_real': 32733.90398213621},
#  {'_id': ObjectId('600381203789f4ca7f3498a9'),
#   'ID': 682729217,
#   'name': 'Authentic Sports Emojis',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 10000.0,
#   'launched': '2014-09-09 00:00:00',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f34854c'),
#   'ID': 410573570,
#   'name': 'Sports TV Tray',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'goal': 30000.0,
#   'launched': '2015-06-08 16:51:41',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f3480a6'),
#   'ID': 1840314169,
#   'name': 'Carolina Sports Bar',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'goal': 15000.0,
#   'launched': '2017-01-17 23:51:59',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f34644b'),
#   'ID': 745138839,
#   'name': 'Tag In! Sports App',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'goal': 15000.0,
#   'launched': '2017-05-04 16:41:08',
#   'state': 'failed',
#   'country': 'CA',
#   'usd_pledged_real': 633.4472003564532},
#  {'_id': ObjectId('600381203789f4ca7f345bff'),
#   'ID': 364919428,
#   'name': 'Sports Fans Bible',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'goal': 5000.0,
#   'launched': '2015-11-30 19:04:36',
#   'state': 'failed',
#   'country': 'CA',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f345a24'),
#   'ID': 1916861953,
#   'name': 'Survival In the Sport of Kings',
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'goal': 7500.0,
#   'launched': '2014-11-01 05:26:55',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1554.0},
#  {'_id': ObjectId('600381203789f4ca7f344ce0'),
#   'ID': 426873967,
#   'name': 'The Lead Sports Media',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'goal': 100000.0,
#   'launched': '2016-08-04 00:20:01',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f3443f5'),
#   'ID': 126254932,
#   'name': 'CineasOne sports Car',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 850000.0,
#   'launched': '2017-01-12 21:02:18',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 25.0},
#  {'_id': ObjectId('600381203789f4ca7f343ada'),
#   'ID': 2088027703,
#   'name': 'Motorcycle Sports Fashion',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'goal': 10000.0,
#   'launched': '2015-12-18 23:21:26',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('600381203789f4ca7f34156a'),
#   'ID': 1961403017,
#   'name': 'Reign sports bar',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'goal': 10000.0,
#   'launched': '2014-08-29 17:44:46',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f3413bc'),
#   'ID': 1516384066,
#   'name': 'Sports, A Celebration of Life',
#   'category': 'Digital Art',
#   'main_category': 'Art',
#   'goal': 28500.0,
#   'launched': '2012-11-17 16:43:07',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 445.0},
#  {'_id': ObjectId('600381203789f4ca7f340dfb'),
#   'ID': 1710786843,
#   'name': 'Maryland Sports Blog',
#   'category': 'Publishing',
#   'main_category': 'Publishing',
#   'goal': 100000.0,
#   'launched': '2015-05-02 06:46:18',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 60.0},
#  {'_id': ObjectId('600381203789f4ca7f340c77'),
#   'ID': 953741564,
#   'name': 'Stumondo Sports Propositions',
#   'category': 'Games',
#   'main_category': 'Games',
#   'goal': 5000.0,
#   'launched': '2017-06-05 01:14:54',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f340b3b'),
#   'ID': 176462982,
#   'name': 'Sports Countdown Calendars',
#   'category': 'Calendars',
#   'main_category': 'Publishing',
#   'goal': 10000.0,
#   'launched': '2017-05-02 01:30:58',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 606.0},
#  {'_id': ObjectId('600381203789f4ca7f33febe'),
#   'ID': 808339685,
#   'name': 'Premium Sport Socks',
#   'category': 'Footwear',
#   'main_category': 'Fashion',
#   'goal': 1000.0,
#   'launched': '2015-08-10 20:28:53',
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f33ef48'),
#   'ID': 17756238,
#   'name': 'Naked Sports Gear',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'goal': 10000.0,
#   'launched': '2012-04-16 16:06:18',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 13210.0},
#  {'_id': ObjectId('600381203789f4ca7f33d055'),
#   'ID': 1541419313,
#   'name': 'Xtreme Sports Italia',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 8500.0,
#   'launched': '2016-05-31 17:23:39',
#   'state': 'canceled',
#   'country': 'IT',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f33c796'),
#   'ID': 1504232892,
#   'name': 'Sports Fans (the movie)',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 50000.0,
#   'launched': '2011-08-23 09:04:02',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 2606.57},
#  {'_id': ObjectId('6003811f3789f4ca7f33c086'),
#   'ID': 888976058,
#   'name': 'Sports Drills (Canceled)',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'goal': 15000.0,
#   'launched': '2015-03-31 22:38:05',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f33a6bd'),
#   'ID': 1337572987,
#   'name': 'Sports Psychology Magazine',
#   'category': 'Print',
#   'main_category': 'Journalism',
#   'goal': 7000.0,
#   'launched': '2014-08-01 23:35:45',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 200.0},
#  {'_id': ObjectId('6003811f3789f4ca7f3392f9'),
#   'ID': 1921371560,
#   'name': 'Sports Shackle Armband',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 10000.0,
#   'launched': '2015-08-29 02:47:22',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 770.0},
#  {'_id': ObjectId('6003811f3789f4ca7f339251'),
#   'ID': 1690062486,
#   'name': 'Redefining Sports Entertainment',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'goal': 50000.0,
#   'launched': '2015-02-27 13:44:09',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 150.0},
#  {'_id': ObjectId('6003811f3789f4ca7f3377cf'),
#   'ID': 1859849153,
#   'name': 'In Search of Sport: Ulama',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 30000.0,
#   'launched': '2015-01-23 07:49:29',
#   'state': 'failed',
#   'country': 'AU',
#   'usd_pledged_real': 1.5656802880851728},
#  {'_id': ObjectId('6003811f3789f4ca7f336133'),
#   'ID': 427315121,
#   'name': 'Crayfish Sports Bar',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'goal': 795000.0,
#   'launched': '2015-08-09 01:27:26',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 10.0},
#  {'_id': ObjectId('6003811f3789f4ca7f334564'),
#   'ID': 767196077,
#   'name': 'New Sports Industry',
#   'category': 'Live Games',
#   'main_category': 'Games',
#   'goal': 700000.0,
#   'launched': '2016-02-10 03:12:28',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('6003811f3789f4ca7f333e77'),
#   'ID': 1699914749,
#   'name': 'Patriot Sports Cards',
#   'category': 'Playing Cards',
#   'main_category': 'Games',
#   'goal': 90000.0,
#   'launched': '2016-03-10 21:24:11',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 2.0},
#  {'_id': ObjectId('6003811f3789f4ca7f3336f9'),
#   'ID': 595778535,
#   'name': 'Sports bag "Infinity"',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 10000.0,
#   'launched': '2016-10-13 15:38:34',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 431.0},
#  {'_id': ObjectId('6003811f3789f4ca7f3312ed'),
#   'ID': 114396613,
#   'name': 'The Sport Revolution on your SmartPhone',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'goal': 4650.0,
#   'launched': '2016-09-30 20:48:23',
#   'state': 'failed',
#   'country': 'ES',
#   'usd_pledged_real': 693.4979118734258},
#  {'_id': ObjectId('6003811f3789f4ca7f32ed9a'),
#   'ID': 1523192703,
#   'name': 'Sport Ball Bags',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'goal': 3000.0,
#   'launched': '2017-04-13 02:07:23',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32eb7a'),
#   'ID': 1388748869,
#   'name': 'Derbyshire Sport Scene',
#   'category': 'Journalism',
#   'main_category': 'Journalism',
#   'goal': 1000.0,
#   'launched': '2014-09-30 00:39:12',
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32dfec'),
#   'ID': 759625825,
#   'name': 'Pickup Sports World',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'goal': 20000.0,
#   'launched': '2017-01-03 02:04:52',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32d8e3'),
#   'ID': 1870839048,
#   'name': 'Sport and Entertainment Podcast',
#   'category': 'Audio',
#   'main_category': 'Journalism',
#   'goal': 2000.0,
#   'launched': '2015-01-15 01:13:35',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 47.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32cef9'),
#   'ID': 2135350794,
#   'name': 'Motor Sports Mailboxes',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'goal': 600000.0,
#   'launched': '2014-11-19 20:20:55',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 200.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32c722'),
#   'ID': 552869945,
#   'name': 'the Indiana Sports Report',
#   'category': 'Web',
#   'main_category': 'Journalism',
#   'goal': 5000.0,
#   'launched': '2014-07-10 17:45:10',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 110.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32b9f1'),
#   'ID': 2035064292,
#   'name': 'SPORTS END TABLES',
#   'category': 'Art',
#   'main_category': 'Art',
#   'goal': 60000.0,
#   'launched': '2015-08-25 19:34:14',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 10.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32b681'),
#   'ID': 22743603,
#   'name': 'Hugodrawings Sports Wear',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'goal': 3000.0,
#   'launched': '2016-06-18 12:04:39',
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged_real': 595.8226936423754},
#  {'_id': ObjectId('6003811f3789f4ca7f32b623'),
#   'ID': 2109408750,
#   'name': 'Biz Sports Weekly',
#   'category': 'Journalism',
#   'main_category': 'Journalism',
#   'goal': 5000.0,
#   'launched': '2016-07-20 16:15:57',
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged_real': 2.617595476795016},
#  {'_id': ObjectId('600381203789f4ca7f34f741'),
#   'ID': 1491511986,
#   'name': 'Wild life & Nature sports',
#   'category': 'Photography',
#   'main_category': 'Photography',
#   'goal': 4000.0,
#   'launched': '2017-11-28 10:11:20',
#   'state': 'live',
#   'country': 'ES',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f34e809'),
#   'ID': 1147840746,
#   'name': 'Varsity Sports Network Makeover',
#   'category': 'Publishing',
#   'main_category': 'Publishing',
#   'goal': 150000.0,
#   'launched': '2014-11-17 22:59:44',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 100.0},
#  {'_id': ObjectId('600381203789f4ca7f34dfbb'),
#   'ID': 1766749777,
#   'name': 'France Retro Sport Jersey',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'goal': 375.0,
#   'launched': '2016-05-26 11:10:59',
#   'state': 'failed',
#   'country': 'ES',
#   'usd_pledged_real': 52.301837241133725},
#  {'_id': ObjectId('600381203789f4ca7f34d5c5'),
#   'ID': 229171863,
#   'name': 'Fanlys - Group Messaging for Sports',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'goal': 5000.0,
#   'launched': '2017-06-28 21:24:58',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f34d2ce'),
#   'ID': 2111331354,
#   'name': 'UK Mountain Sport Bible',
#   'category': 'Web',
#   'main_category': 'Journalism',
#   'goal': 5000.0,
#   'launched': '2015-08-14 13:53:30',
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged_real': 30.67908146830084},
#  {'_id': ObjectId('600381203789f4ca7f34adb3'),
#   'ID': 504390687,
#   'name': 'Invicto Mode / Sport Schuhe',
#   'category': 'Footwear',
#   'main_category': 'Fashion',
#   'goal': 10000.0,
#   'launched': '2016-07-30 04:36:09',
#   'state': 'failed',
#   'country': 'DE',
#   'usd_pledged_real': 304.6708648575182},
#  {'_id': ObjectId('600381203789f4ca7f3495ad'),
#   'ID': 972594339,
#   'name': 'Clincher Hockey Sports Bottle',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 7000.0,
#   'launched': '2017-04-26 23:45:59',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 38.0},
#  {'_id': ObjectId('600381203789f4ca7f348b7b'),
#   'ID': 1091093954,
#   'name': 'Paralympic Sport Stars Documentary',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 10000.0,
#   'launched': '2014-07-06 20:31:29',
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged_real': 33.65133848198812},
#  {'_id': ObjectId('600381203789f4ca7f3489cf'),
#   'ID': 1710000457,
#   'name': 'GoTabs Portable Sports Drink',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'goal': 20000.0,
#   'launched': '2014-05-30 22:39:49',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('600381203789f4ca7f347173'),
#   'ID': 1225408944,
#   'name': 'Action Sports Capital of the World',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 25000.0,
#   'launched': '2015-08-02 01:19:11',
#   'state': 'failed',
#   'country': 'AU',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f346666'),
#   'ID': 142727970,
#   'name': 'Sports For the Masses: A Fingerprint Installation',
#   'category': 'Art',
#   'main_category': 'Art',
#   'goal': 1500.0,
#   'launched': '2011-05-25 23:43:59',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 1500.0},
#  {'_id': ObjectId('600381203789f4ca7f344fed'),
#   'ID': 1937397095,
#   'name': 'Sports Widow Mobile App',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'goal': 30000.0,
#   'launched': '2015-02-04 15:47:27',
#   'state': 'failed',
#   'country': 'IE',
#   'usd_pledged_real': 69.06683038063497},
#  {'_id': ObjectId('600381203789f4ca7f344ce8'),
#   'ID': 1672762881,
#   'name': 'Fanatalks - A website for sports fans',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'goal': 10000.0,
#   'launched': '2015-11-06 17:01:51',
#   'state': 'failed',
#   'country': 'CA',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f33fa77'),
#   'ID': 1548994917,
#   'name': 'Shoes to Show your Spirit for Sports',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'goal': 1000.0,
#   'launched': '2014-09-04 05:23:25',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f33eede'),
#   'ID': 114287621,
#   'name': 'A League About Nothing: If Seinfeld was a Sport',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'goal': 2000.0,
#   'launched': '2013-01-29 22:51:07',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 6064.0},
#  {'_id': ObjectId('600381203789f4ca7f33e76c'),
#   'ID': 88714878,
#   'name': 'Sports4App: Play sports with people',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'goal': 7500.0,
#   'launched': '2017-06-21 11:32:32',
#   'state': 'failed',
#   'country': 'ES',
#   'usd_pledged_real': 87.31489242805254},
#  {'_id': ObjectId('600381203789f4ca7f33cfe0'),
#   'ID': 1292450411,
#   'name': 'Cultural Pretzel Sports Bar',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'goal': 20000.0,
#   'launched': '2016-02-10 07:51:47',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 35.0},
#  {'_id': ObjectId('600381203789f4ca7f33cee5'),
#   'ID': 40163379,
#   'name': 'Project "TAG" - Sports Decks',
#   'category': 'Live Games',
#   'main_category': 'Games',
#   'goal': 15000.0,
#   'launched': '2016-10-11 18:21:02',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 690.0},
#  {'_id': ObjectId('600381203789f4ca7f33c891'),
#   'ID': 1250536292,
#   'name': 'The ProHand: Sports Training Tool',
#   'category': 'Design',
#   'main_category': 'Design',
#   'goal': 8000.0,
#   'launched': '2014-03-11 04:16:26',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 20.0},
#  {'_id': ObjectId('6003811f3789f4ca7f33b291'),
#   'ID': 1457772640,
#   'name': 'Sports Konnect  iPhone  App',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 8000.0,
#   'launched': '2015-12-03 17:07:00',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 50.0},
#  {'_id': ObjectId('6003811f3789f4ca7f33b26f'),
#   'ID': 1637902669,
#   'name': 'Finally, A Sports Bra with Pockets',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'goal': 3000.0,
#   'launched': '2013-06-28 16:58:28',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 3871.0},
#  {'_id': ObjectId('6003811f3789f4ca7f3394dd'),
#   'ID': 14759036,
#   'name': "Hal's Take on Sports Podcast!",
#   'category': 'Performance Art',
#   'main_category': 'Art',
#   'goal': 7200.0,
#   'launched': '2012-07-20 22:54:37',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 35.0},
#  {'_id': ObjectId('6003811f3789f4ca7f339066'),
#   'ID': 864444586,
#   'name': 'Sports Data Analytics Exhibition',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'goal': 5000.0,
#   'launched': '2015-08-04 15:18:56',
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged_real': 352.0520724131996},
#  {'_id': ObjectId('6003811f3789f4ca7f338c7c'),
#   'ID': 2008099012,
#   'name': "Sportzgirlz - Women's Sports Coverage",
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 4400.0,
#   'launched': '2015-01-28 22:45:39',
#   'state': 'failed',
#   'country': 'AU',
#   'usd_pledged_real': 1.5656802880851728},
#  {'_id': ObjectId('6003811f3789f4ca7f338808'),
#   'ID': 1748145851,
#   'name': "Battle Buddy's sports bar",
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'goal': 8500.0,
#   'launched': '2015-11-17 18:12:21',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 55.0},
#  {'_id': ObjectId('6003811f3789f4ca7f33683f'),
#   'ID': 647933794,
#   'name': 'Jewish Sports Heritage Magazine',
#   'category': 'Literary Journals',
#   'main_category': 'Publishing',
#   'goal': 7500.0,
#   'launched': '2014-10-07 21:23:25',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 10.0},
#  {'_id': ObjectId('6003811f3789f4ca7f335bcd'),
#   'ID': 833299467,
#   'name': 'The World of United Sport (Canceled)',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'goal': 2600.0,
#   'launched': '2015-12-29 21:59:22',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f335961'),
#   'ID': 1938753898,
#   'name': 'Basketball Coaching Tutorial (Sports)',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'goal': 1500.0,
#   'launched': '2016-07-07 19:43:50',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 199.0},
#  {'_id': ObjectId('6003811f3789f4ca7f33573a'),
#   'ID': 1084596137,
#   'name': 'Posters! Of animals! Playing sports!',
#   'category': 'Graphic Design',
#   'main_category': 'Design',
#   'goal': 4000.0,
#   'launched': '2012-11-07 19:15:06',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 4887.0},
#  {'_id': ObjectId('6003811f3789f4ca7f334f80'),
#   'ID': 496229694,
#   'name': 'IU: Sports and Travel Vest',
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'goal': 35000.0,
#   'launched': '2015-07-13 17:49:57',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 761.0},
#  {'_id': ObjectId('6003811f3789f4ca7f333701'),
#   'ID': 374746825,
#   'name': 'Instant, Mobile, Fantasy Sports.',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 30000.0,
#   'launched': '2013-08-20 01:23:08',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 30637.0},
#  {'_id': ObjectId('6003811f3789f4ca7f333205'),
#   'ID': 684627152,
#   'name': 'Dream Skating Sports Planner',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'goal': 5000.0,
#   'launched': '2015-03-02 22:24:11',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 400.0},
#  {'_id': ObjectId('6003811f3789f4ca7f3328ee'),
#   'ID': 137733484,
#   'name': "'Cursed' - The Cleveland Sports Story",
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 35000.0,
#   'launched': '2011-11-08 21:19:16',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 425.0},
#  {'_id': ObjectId('6003811f3789f4ca7f331caa'),
#   'ID': 1275259290,
#   'name': 'iWhite - Sport Nutrition - Restaurant',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'goal': 140000.0,
#   'launched': '2015-09-17 13:32:30',
#   'state': 'failed',
#   'country': 'DE',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32f65a'),
#   'ID': 1792640178,
#   'name': 'JOIN THE MUSIC-SPORTS MOVEMENT!',
#   'category': 'Music',
#   'main_category': 'Music',
#   'goal': 1500.0,
#   'launched': '2016-11-29 15:04:19',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32f185'),
#   'ID': 87488242,
#   'name': 'SnapDrafts: Daily Fantasy Sports',
#   'category': 'Live Games',
#   'main_category': 'Games',
#   'goal': 100000.0,
#   'launched': '2015-03-26 21:48:26',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 500.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32ee59'),
#   'ID': 784739167,
#   'name': 'KYMIRA Sport: An Evolution in Sportswear',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'goal': 25000.0,
#   'launched': '2014-04-16 14:03:31',
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged_real': 23369.528676124522},
#  {'_id': ObjectId('6003811f3789f4ca7f32ebfc'),
#   'ID': 33300581,
#   'name': 'Cyber Sports Monthly (Canceled)',
#   'category': 'Periodicals',
#   'main_category': 'Publishing',
#   'goal': 15000.0,
#   'launched': '2012-12-23 17:08:32',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 162.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32e85b'),
#   'ID': 844622643,
#   'name': 'Pro League E-Sports',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 50000.0,
#   'launched': '2016-06-20 23:01:57',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 500.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32d774'),
#   'ID': 12584764,
#   'name': 'Sports Cards Unlimited (Canceled)',
#   'category': 'Playing Cards',
#   'main_category': 'Games',
#   'goal': 400000.0,
#   'launched': '2015-10-16 21:19:00',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32ca85'),
#   'ID': 1696158836,
#   'name': 'Sports Card Magazine is ready!',
#   'category': 'Journalism',
#   'main_category': 'Journalism',
#   'goal': 5000.0,
#   'launched': '2013-01-13 01:12:18',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 590.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32c31c'),
#   'ID': 205654323,
#   'name': 'Sports, Fitness and Faith magazine',
#   'category': 'Periodicals',
#   'main_category': 'Publishing',
#   'goal': 20000.0,
#   'launched': '2016-04-13 19:05:24',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 127.0},
#  {'_id': ObjectId('600381203789f4ca7f34ea92'),
#   'ID': 645692773,
#   'name': 'Worlds Collide Sports & Comics Bar',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'goal': 100000.0,
#   'launched': '2016-02-22 20:10:35',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f34bd73'),
#   'ID': 423826472,
#   'name': 'TrigSport/ sport social network prototype',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'goal': 7000.0,
#   'launched': '2015-10-09 18:06:30',
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged_real': 1.5223712454519165},
#  {'_id': ObjectId('600381203789f4ca7f34ba25'),
#   'ID': 1304467963,
#   'name': 'Opinionated Sports Online Fantasy Games',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 5000.0,
#   'launched': '2017-05-31 03:38:31',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('600381203789f4ca7f34b533'),
#   'ID': 197829569,
#   'name': 'Predicting the Outcome of Sports Using Bo!',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'goal': 4999.0,
#   'launched': '2015-04-20 20:14:49',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f34b023'),
#   'ID': 968097705,
#   'name': 'Sport Bumper: Protecting Your Ride and Your Gear',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 5000.0,
#   'launched': '2013-09-26 23:22:45',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 8091.0},
#  {'_id': ObjectId('600381203789f4ca7f347b59'),
#   'ID': 1586561826,
#   'name': "Byfield's Sports Photography & Graphic Design",
#   'category': 'People',
#   'main_category': 'Photography',
#   'goal': 15000.0,
#   'launched': '2015-07-03 03:05:40',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 40.0},
#  {'_id': ObjectId('600381203789f4ca7f347130'),
#   'ID': 1533072925,
#   'name': 'Spoon River Online Sports Broadcasting',
#   'category': 'Web',
#   'main_category': 'Journalism',
#   'goal': 10000.0,
#   'launched': '2014-10-30 20:18:55',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f346966'),
#   'ID': 223598354,
#   'name': 'Red Combat Action Sports Entertainment',
#   'category': 'Action',
#   'main_category': 'Film & Video',
#   'goal': 100000.0,
#   'launched': '2015-03-14 07:05:31',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f346770'),
#   'ID': 277461164,
#   'name': 'SHARK SHIRT Sport Polo (Canceled)',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 3000.0,
#   'launched': '2014-08-12 03:57:54',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f345af0'),
#   'ID': 1063565534,
#   'name': 'News.Sport.Weather iOS application',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 7000.0,
#   'launched': '2013-08-28 22:30:31',
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged_real': 35.454135241410434},
#  {'_id': ObjectId('600381203789f4ca7f34341d'),
#   'ID': 1856536686,
#   'name': 'Custom Technology Sleeves by Eagle Sports',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'goal': 7000.0,
#   'launched': '2016-01-04 20:48:05',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f342ee8'),
#   'ID': 1016098786,
#   'name': 'SoccerBrawl! The future of action-sport gaming',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 40000.0,
#   'launched': '2017-03-01 22:59:36',
#   'state': 'canceled',
#   'country': 'GB',
#   'usd_pledged_real': 268.67275658248246},
#  {'_id': ObjectId('600381203789f4ca7f342cc9'),
#   'ID': 1422299371,
#   'name': 'VRYPAC - The Minimalist Backpack for Sports & Travel',
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'goal': 3500.0,
#   'launched': '2017-08-31 17:35:10',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 3950.0},
#  {'_id': ObjectId('600381203789f4ca7f341a79'),
#   'ID': 109716341,
#   'name': 'The Ultimate Biliztik Sports App   "It\'s Time"',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'goal': 20000.0,
#   'launched': '2015-11-11 19:18:18',
#   'state': 'failed',
#   'country': 'CA',
#   'usd_pledged_real': 2510.7480653482376},
#  {'_id': ObjectId('600381203789f4ca7f34187d'),
#   'ID': 691895706,
#   'name': 'Say Goodbye to Traditional Sports Coverage',
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'goal': 16000.0,
#   'launched': '2011-03-16 07:51:30',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f3412b0'),
#   'ID': 99326056,
#   'name': 'BetHero: Social betting on sport (Canceled)',
#   'category': 'Mobile Games',
#   'main_category': 'Games',
#   'goal': 5000.0,
#   'launched': '2014-06-21 13:57:02',
#   'state': 'canceled',
#   'country': 'GB',
#   'usd_pledged_real': 126.03135660152245},
#  {'_id': ObjectId('600381203789f4ca7f33fc80'),
#   'ID': 1453869545,
#   'name': 'Practicity | The Intuitive Sports Practice Website |',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'goal': 25000.0,
#   'launched': '2015-05-08 00:46:22',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f33fb02'),
#   'ID': 1270458613,
#   'name': 'Epirus: Tennis bags as stylish as the sport itself',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 20000.0,
#   'launched': '2016-10-18 09:30:32',
#   'state': 'successful',
#   'country': 'GB',
#   'usd_pledged_real': 25895.0145470684},
#  {'_id': ObjectId('600381203789f4ca7f33f6a2'),
#   'ID': 1666992653,
#   'name': 'E sports cafe and lounge (Canceled)',
#   'category': 'Live Games',
#   'main_category': 'Games',
#   'goal': 100000.0,
#   'launched': '2015-04-09 16:36:16',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f33f0c0'),
#   'ID': 170140840,
#   'name': 'ARIIS - The Most Versatile Sports Performance Monitor',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'goal': 5500.0,
#   'launched': '2016-10-17 17:45:43',
#   'state': 'successful',
#   'country': 'CA',
#   'usd_pledged_real': 4716.981132075472},
#  {'_id': ObjectId('600381203789f4ca7f33f033'),
#   'ID': 1477969256,
#   'name': 'North Roanoke County Sports Magazine',
#   'category': 'Publishing',
#   'main_category': 'Publishing',
#   'goal': 6500.0,
#   'launched': '2015-07-09 02:03:08',
#   'state': 'undefined',
#   'country': 'N,0"',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f33d384'),
#   'ID': 1646833220,
#   'name': 'Shefit Sports Bra & Fitness Apparel',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'goal': 18000.0,
#   'launched': '2013-08-16 14:37:06',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 20448.0},
#  {'_id': ObjectId('6003811f3789f4ca7f33c003'),
#   'ID': 1330442354,
#   'name': 'E-sports squad looking for Jerseys!',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 500.0,
#   'launched': '2015-02-20 11:19:06',
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f33be30'),
#   'ID': 2047720532,
#   'name': 'The Effects of Marketing Sports Supplements to Adolescents',
#   'category': 'Academic',
#   'main_category': 'Publishing',
#   'goal': 5000.0,
#   'launched': '2016-07-29 19:22:10',
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged_real': 1.3283917161492582},
#  {'_id': ObjectId('6003811f3789f4ca7f33a9a8'),
#   'ID': 312713193,
#   'name': 'Essential Tips for Coaching Youth Sports',
#   'category': 'Publishing',
#   'main_category': 'Publishing',
#   'goal': 4500.0,
#   'launched': '2015-09-03 20:45:00',
#   'state': 'undefined',
#   'country': 'N,0"',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f33983f'),
#   'ID': 48452566,
#   'name': '"Watchaholics Anonymous (Sports!)" (web-tv)',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'goal': 1000.0,
#   'launched': '2011-04-16 23:09:33',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 1010.0},
#  {'_id': ObjectId('6003811f3789f4ca7f33983e'),
#   'ID': 1524520456,
#   'name': 'HOBB-Sport experiences with Local passionates',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'goal': 10000.0,
#   'launched': '2016-10-19 19:22:47',
#   'state': 'failed',
#   'country': 'FR',
#   'usd_pledged_real': 1.062902574350035},
#  {'_id': ObjectId('6003811f3789f4ca7f33747a'),
#   'ID': 2094312119,
#   'name': 'Buena High Aquatic Sports Mural',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'goal': 1500.0,
#   'launched': '2013-01-09 16:24:20',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 1608.0},
#  {'_id': ObjectId('6003811f3789f4ca7f33731d'),
#   'ID': 307748810,
#   'name': 'TRUEnergy - Green Tea Sports Shot',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'goal': 20000.0,
#   'launched': '2015-11-17 15:03:02',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 22723.0},
#  {'_id': ObjectId('6003811f3789f4ca7f336f44'),
#   'ID': 1298882779,
#   'name': "First Women's Sports Network: MyWSports",
#   'category': 'Journalism',
#   'main_category': 'Journalism',
#   'goal': 50000.0,
#   'launched': '2015-11-17 17:59:13',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 50.0},
#  {'_id': ObjectId('6003811f3789f4ca7f336a0c'),
#   'ID': 1577431293,
#   'name': 'Keep MSA Sports in Western PA!',
#   'category': 'Audio',
#   'main_category': 'Journalism',
#   'goal': 85000.0,
#   'launched': '2017-08-04 22:00:34',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 21363.0},
#  {'_id': ObjectId('6003811f3789f4ca7f33546f'),
#   'ID': 1380764438,
#   'name': 'Mi Sports Profile - Prepare to Succeed',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'goal': 35000.0,
#   'launched': '2014-09-10 15:14:52',
#   'state': 'failed',
#   'country': 'AU',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f3351d4'),
#   'ID': 619119405,
#   'name': 'Strive Thru Sports - AIM High',
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'goal': 10000.0,
#   'launched': '2014-08-30 00:35:12',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 100.0},
#  {'_id': ObjectId('6003811f3789f4ca7f334b00'),
#   'ID': 558384208,
#   'name': 'Sports Stadium Iphone App Development',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'goal': 500.0,
#   'launched': '2015-05-14 03:35:49',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f3335d0'),
#   'ID': 1741756528,
#   'name': 'Spotbook Spot?s for Sport?s',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'goal': 10000.0,
#   'launched': '2015-05-16 00:35:18',
#   'state': 'failed',
#   'country': 'DE',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f333011'),
#   'ID': 1935189722,
#   'name': 'KickFlip Mafia Action Sports Clothing',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'goal': 5000.0,
#   'launched': '2012-06-11 22:05:27',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f332a73'),
#   'ID': 69383759,
#   'name': '"ACTION" A Gallery Showing For Action Sports',
#   'category': 'Shorts',
#   'main_category': 'Film & Video',
#   'goal': 5000.0,
#   'launched': '2010-10-25 04:29:03',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f3329fd'),
#   'ID': 1771971822,
#   'name': 'Bright Stools:  Any Sport, Any Season, Any Event.',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 200000.0,
#   'launched': '2014-11-13 05:51:00',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 2893.0},
#  {'_id': ObjectId('6003811f3789f4ca7f332874'),
#   'ID': 746676343,
#   'name': 'The 90 Degree Show on NBC Sports',
#   'category': 'Music',
#   'main_category': 'Music',
#   'goal': 1800.0,
#   'launched': '2017-09-28 23:17:29',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 173.0},
#  {'_id': ObjectId('6003811f3789f4ca7f3326c6'),
#   'ID': 2014871717,
#   'name': 'DJBennett.com The World of SPORTING LUXURY',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'goal': 500000.0,
#   'launched': '2015-03-10 17:01:31',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32f7b3'),
#   'ID': 422509694,
#   'name': '"American Sports Stories" - An Athletic Quest',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'goal': 100000.0,
#   'launched': '2017-04-14 00:08:52',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32ee1e'),
#   'ID': 1018822517,
#   'name': 'Massive LEGO Truman Sports Complex',
#   'category': 'Sculpture',
#   'main_category': 'Art',
#   'goal': 16137.0,
#   'launched': '2014-07-19 23:53:29',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32cdbd'),
#   'ID': 1854354367,
#   'name': 'Learn a Foreign Language While Playing Sports',
#   'category': 'Design',
#   'main_category': 'Design',
#   'goal': 2500.0,
#   'launched': '2015-04-21 21:29:27',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32cb4e'),
#   'ID': 865678989,
#   'name': 'Avada Gaming E-Sports Organisation',
#   'category': 'Games',
#   'main_category': 'Games',
#   'goal': 1000.0,
#   'launched': '2014-07-16 02:15:51',
#   'state': 'failed',
#   'country': 'AU',
#   'usd_pledged_real': 4.655926995064717},
#  {'_id': ObjectId('6003811f3789f4ca7f32c799'),
#   'ID': 1293757259,
#   'name': 'Unique handmade leather sports roses',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'goal': 2000.0,
#   'launched': '2014-08-06 22:29:49',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 27.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32c0c7'),
#   'ID': 321623835,
#   'name': 'DV8 Sports: Golf Without Obstacles',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 50000.0,
#   'launched': '2014-06-10 08:35:40',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 85442.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32b51d'),
#   'ID': 369230992,
#   'name': 'ULTIMMADMAN - action sports apparel   #JustBeTough',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'goal': 5000.0,
#   'launched': '2012-09-10 03:48:17',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 60.0},
#  {'_id': ObjectId('600381203789f4ca7f34f882'),
#   'ID': 1966574528,
#   'name': 'The Sports Towel - Help take my product to market.',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'goal': 16625.0,
#   'launched': '2016-02-12 01:16:51',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 261.0},
#  {'_id': ObjectId('600381203789f4ca7f34f7e7'),
#   'ID': 1007112532,
#   'name': 'LoopBall: the first Bluetooth connected sport ball !',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 45000.0,
#   'launched': '2017-06-20 09:33:21',
#   'state': 'failed',
#   'country': 'FR',
#   'usd_pledged_real': 5248.041775456919},
#  {'_id': ObjectId('600381203789f4ca7f34f4da'),
#   'ID': 367445085,
#   'name': "The world's best Sports, Travel and Outdoor Jacket",
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 30000.0,
#   'launched': '2017-12-11 16:05:56',
#   'state': 'live',
#   'country': 'AT',
#   'usd_pledged_real': 131330.33146019685},
#  {'_id': ObjectId('600381203789f4ca7f34e650'),
#   'ID': 38175482,
#   'name': 'Xrossgear - The new definition of extreme sports apparel',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'goal': 9700.0,
#   'launched': '2011-11-07 06:43:40',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f34e4d7'),
#   'ID': 1003481744,
#   'name': 'CONDUIT Sports - Dynamic Bone Conducting Headphones',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'goal': 50000.0,
#   'launched': '2017-04-10 21:11:10',
# ...
#   'usd_pledged_real': 567.0},
#  {'_id': ObjectId('6003811f3789f4ca7f3360fc'),
#   'ID': 244965866,
#   'name': 'Ethical Polo: The Ultimate Sports Fit Polo Shirt',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'goal': 15000.0,
#   'launched': '2016-10-09 18:01:17',
#   'state': 'failed',
#   'country': 'AU',
#   'usd_pledged_real': 344.6222553033124},
#  {'_id': ObjectId('6003811f3789f4ca7f334d33'),
#   'ID': 1336212200,
#   'name': 'KICKSTARTER Shoulder Strap for Laptop, Sport and Travel bags',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'goal': 1000.0,
#   'launched': '2016-07-10 08:06:39',
#   'state': 'successful',
#   'country': 'DE',
#   'usd_pledged_real': 3086.069900538979},
#  {'_id': ObjectId('6003811f3789f4ca7f334a09'),
#   'ID': 393590800,
#   'name': "Earl of Arlington's Prize - youth sports award medal",
#   'category': 'Sculpture',
#   'main_category': 'Art',
#   'goal': 500.0,
#   'launched': '2013-11-07 19:02:27',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 500.0},
#  {'_id': ObjectId('6003811f3789f4ca7f33424b'),
#   'ID': 889804160,
#   'name': 'Combat Sports Hall of Fame - Establishing Online Exhibitions',
#   'category': 'Art',
#   'main_category': 'Art',
#   'goal': 4000.0,
#   'launched': '2014-10-14 18:32:03',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 925.0},
#  {'_id': ObjectId('6003811f3789f4ca7f334060'),
#   'ID': 862046750,
#   'name': 'Bestia Fight Gear MMA sports products and sponsorships',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'goal': 8000.0,
#   'launched': '2014-12-17 06:16:11',
#   'state': 'failed',
#   'country': 'CA',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f333f90'),
#   'ID': 1035330015,
#   'name': 'Matano: Fair Trade Sports Apparel for the Everyday Athlete',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'goal': 20000.0,
#   'launched': '2016-05-31 15:01:49',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 6717.0},
#  {'_id': ObjectId('6003811f3789f4ca7f332cc4'),
#   'ID': 2083908527,
#   'name': 'Build a Large Scale Version  of the Airsailer Sports Balloon',
#   'category': 'Flight',
#   'main_category': 'Technology',
#   'goal': 47600.0,
#   'launched': '2014-08-12 08:28:36',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 17.0},
#  {'_id': ObjectId('6003811f3789f4ca7f3321b6'),
#   'ID': 1658515944,
#   'name': 'Super Slam Dunk Touchdown: A Sports Game For Everybody!',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 15000.0,
#   'launched': '2015-02-27 03:17:00',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 5428.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32ff6e'),
#   'ID': 312464012,
#   'name': 'Loopio & Loopio Sport | Never lose your keys or phone again.',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 30000.0,
#   'launched': '2015-05-13 23:18:04',
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged_real': 11816.97234628908},
#  {'_id': ObjectId('6003811f3789f4ca7f32e9a5'),
#   'ID': 415048408,
#   'name': '500 Level: Unique Officially Licensed Sports Tshirts',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'goal': 20000.0,
#   'launched': '2013-07-14 19:07:09',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 21213.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32ba04'),
#   'ID': 1362109613,
#   'name': 'LA LAKERS Inspired Sports + Lifestyle Jewelry for the Fans',
#   'category': 'Jewelry',
#   'main_category': 'Fashion',
#   'goal': 5100.0,
#   'launched': '2016-10-04 19:14:36',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 2228.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32b491'),
#   'ID': 1838460041,
#   'name': 'Mount Systems for Recreation Sports & Film (GoPro) Lighting',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'goal': 30000.0,
#   'launched': '2015-05-12 18:34:28',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 12442.0},
#  {'_id': ObjectId('600381203789f4ca7f34dea0'),
#   'ID': 148270105,
#   'name': 'Tawny Shark: Sport Watch Inspired By Pilot And Solar System',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 10000.0,
#   'launched': '2015-08-31 02:57:05',
#   'state': 'successful',
#   'country': 'CA',
#   'usd_pledged_real': 18731.864588930683},
#  {'_id': ObjectId('600381203789f4ca7f34b7e3'),
#   'ID': 310904408,
#   'name': 'PROJECT X - Sports Based Reality TV Show (Canceled)',
#   'category': 'Television',
#   'main_category': 'Film & Video',
#   'goal': 18000.0,
#   'launched': '2014-07-03 03:47:17',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f348336'),
#   'ID': 75524259,
#   'name': 'Hobby Sport Media: Help make 2014 EPIC!!! (Canceled)',
#   'category': 'Photography',
#   'main_category': 'Photography',
#   'goal': 6500.0,
#   'launched': '2014-03-08 00:01:06',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f346aac'),
#   'ID': 2031565274,
#   'name': 'A Day in the Life - Season 2 Internet Action Sports Series',
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'goal': 1950.0,
#   'launched': '2012-11-03 06:19:57',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f345e78'),
#   'ID': 120601501,
#   'name': "World's Best Travel Bag & Jacket (Sports, Multipurpose bag)",
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 7500.0,
#   'launched': '2016-11-10 14:01:08',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 6620.0},
#  {'_id': ObjectId('600381203789f4ca7f341313'),
#   'ID': 189342553,
#   'name': 'Coaches IQ Fantasy Sports Real-Time Interactive Game',
#   'category': 'Gaming Hardware',
#   'main_category': 'Games',
#   'goal': 20000.0,
#   'launched': '2015-10-08 04:05:39',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f3410d3'),
#   'ID': 821911962,
#   'name': 'Bleacher League - Making Social Sports Betting Fun and Legal',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'goal': 100000.0,
#   'launched': '2012-01-03 15:06:39',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 275.0},
#  {'_id': ObjectId('600381203789f4ca7f3408ea'),
#   'ID': 719864547,
#   'name': 'Natural Athlete - Advert Free Magazine Promoting Clean Sport',
#   'category': 'Nonfiction',
#   'main_category': 'Publishing',
#   'goal': 5000.0,
#   'launched': '2015-08-08 11:46:05',
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged_real': 139.25615308788787},
#  {'_id': ObjectId('600381203789f4ca7f340773'),
#   'ID': 1442562864,
#   'name': 'Find gym or sports studio in San Francisco bay area',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'goal': 30000.0,
#   'launched': '2015-03-25 06:09:03',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f33bfd8'),
#   'ID': 1357245004,
#   'name': 'World first photochromic bi focal sports / cycling sunglass.',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 42000.0,
#   'launched': '2015-09-03 03:20:53',
#   'state': 'failed',
#   'country': 'AU',
#   'usd_pledged_real': 3028.4374083846387},
#  {'_id': ObjectId('6003811f3789f4ca7f33b7a0'),
#   'ID': 1533951471,
#   'name': "Al's Steakhouse & Sports Bar-Home of our VFW Post #5159",
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'goal': 77793.0,
#   'launched': '2015-02-05 01:55:27',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f33960b'),
#   'ID': 1942009790,
#   'name': 'Coche de lujo Smilodon GT900 Super Sport Car',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 400000.0,
#   'launched': '2017-08-29 15:59:23',
#   'state': 'failed',
#   'country': 'ES',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('6003811f3789f4ca7f339322'),
#   'ID': 846903542,
#   'name': 'MANAGE Youth to Adult (Sports Team & Band/Orchestra) INFO...',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 200000.0,
#   'launched': '2013-09-28 16:51:08',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 50.0},
#  {'_id': ObjectId('6003811f3789f4ca7f3365df'),
#   'ID': 1661563672,
#   'name': 'Jalape?oï¿½ | Portable Beat Maker for Action Sports',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'goal': 53000.0,
#   'launched': '2014-01-08 14:59:52',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 10424.0},
#  {'_id': ObjectId('6003811f3789f4ca7f336079'),
#   'ID': 1133648228,
#   'name': 'DIY Wateproof Kit For Earbuds & mp3 players Made For Sports',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 4500.0,
#   'launched': '2014-10-08 20:57:13',
#   'state': 'canceled',
#   'country': 'GB',
#   'usd_pledged_real': 1.5654596972400947},
#  {'_id': ObjectId('6003811f3789f4ca7f334872'),
#   'ID': 1759789985,
#   'name': 'LUMA ACTIVE: First-ever lighting headgear for outdoor sports',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'goal': 15000.0,
#   'launched': '2015-10-21 07:45:44',
#   'state': 'successful',
#   'country': 'AT',
#   'usd_pledged_real': 24565.69119109588},
#  {'_id': ObjectId('6003811f3789f4ca7f333912'),
#   'ID': 2049335955,
#   'name': 'Innovative nursing bra built-in tank, dress and sports bra',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 10000.0,
#   'launched': '2017-08-01 01:32:29',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 19400.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32f896'),
#   'ID': 2073829586,
#   'name': 'FLootball.com- A Fantasy Football, RPG, Sports game Mashup',
#   'category': 'Games',
#   'main_category': 'Games',
#   'goal': 20000.0,
#   'launched': '2015-03-17 17:01:30',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 110.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32ecc4'),
#   'ID': 1916832,
#   'name': 'Dog Power: A Look Into the Fastest Dogs & Newest Dog Sports',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'goal': 33462.0,
#   'launched': '2015-10-16 21:46:25',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 34858.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32d24b'),
#   'ID': 615962126,
#   'name': 'SUB - SPORTS UTILITY BAG - Bold, Tough, Ultra Versatile',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 15000.0,
#   'launched': '2015-03-23 17:00:15',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 7175.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32b584'),
#   'ID': 1773369191,
#   'name': '2Rare Taylor photo Magazine: Amazing Women and sports cars',
#   'category': 'Photobooks',
#   'main_category': 'Photography',
#   'goal': 15000.0,
#   'launched': '2017-09-28 01:32:49',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 65.0},
#  {'_id': ObjectId('600381203789f4ca7f34ed26'),
#   'ID': 9576483,
#   'name': 'Custom Official Sports Logo Rings - NCAA, NHL, NBA & NASCAR',
#   'category': 'Jewelry',
#   'main_category': 'Fashion',
#   'goal': 1000.0,
#   'launched': '2017-01-25 23:17:46',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 101.0},
#  {'_id': ObjectId('600381203789f4ca7f34e973'),
#   'ID': 2134681345,
#   'name': 'GPS DATUM Sports HD 1080p 60fps camera, Wireless Network',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 20000.0,
#   'launched': '2013-04-08 19:46:17',
#   'state': 'canceled',
#   'country': 'GB',
#   'usd_pledged_real': 1076.8236778143557},
#  {'_id': ObjectId('600381203789f4ca7f347e43'),
#   'ID': 1228592468,
#   'name': 'TOP KIT SPORTS GEAR BAGS: Destroy the Duffle Bag (Canceled)',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 22500.0,
#   'launched': '2013-06-21 07:44:22',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 2310.0},
#  {'_id': ObjectId('600381203789f4ca7f3408ec'),
#   'ID': 910006897,
#   'name': 'Garbage Time Pros Trading Cards Series 1 (Sports Satire)',
#   'category': 'Illustration',
#   'main_category': 'Art',
#   'goal': 35000.0,
#   'launched': '2014-03-07 03:24:07',
#   'state': 'canceled',
#   'country': 'US',
#   'usd_pledged_real': 90.0},
#  {'_id': ObjectId('600381203789f4ca7f33c54a'),
#   'ID': 71558538,
#   'name': 'RUBY & FROST SPORT-Look Good.Exercise Better.Be eco-friendly',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 10000.0,
#   'launched': '2014-08-14 23:57:18',
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged_real': 26.145072470872755},
#  {'_id': ObjectId('6003811f3789f4ca7f33588a'),
#   'ID': 1728490690,
#   'name': 'Carat Pro - Heart Rate Monitor & 4GB Storage Sport Earbuds',
#   'category': 'Sound',
#   'main_category': 'Technology',
#   'goal': 50000.0,
#   'launched': '2016-12-06 14:05:04',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 51881.0},
#  {'_id': ObjectId('6003811f3789f4ca7f332459'),
#   'ID': 729181791,
#   'name': 'Poor Sports- iBook created by a 6 year old Creative Wizard',
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'goal': 1500.0,
#   'launched': '2013-03-06 18:54:06',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 410.0},
#  {'_id': ObjectId('6003811f3789f4ca7f330021'),
#   'ID': 1222567604,
#   'name': "Altered V3 DS - World's First Dual Sport Electric Skateboard",
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'goal': 50000.0,
#   'launched': '2013-10-22 21:53:06',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 22815.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32f205'),
#   'ID': 1959821013,
#   'name': "Get Real Girl: Sport action figures empowering today's girls",
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'goal': 40000.0,
#   'launched': '2016-10-20 19:15:14',
#   'state': 'successful',
#   'country': 'US',
#   'usd_pledged_real': 44305.33},
#  {'_id': ObjectId('6003811f3789f4ca7f32deac'),
#   'ID': 946363782,
#   'name': 'Help us Launch AGON - New Sports Medicine Apparel Brand',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'goal': 80000.0,
#   'launched': '2016-03-04 03:32:26',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 19.0},
#  {'_id': ObjectId('6003811f3789f4ca7f32be4f'),
#   'ID': 2144020477,
#   'name': 'ST Impact Ball: Reduce play and sport related brain injuries',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'goal': 45000.0,
#   'launched': '2014-10-21 21:06:48',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 80.0},
#  {'_id': ObjectId('600381203789f4ca7f34dd82'),
#   'ID': 126588602,
#   'name': 'Behinderten gerechtes Sport/Kaj?tboot, Gr??e 10 - 12 m',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'goal': 3000000.0,
#   'launched': '2016-04-25 18:06:17',
#   'state': 'failed',
#   'country': 'DE',
#   'usd_pledged_real': 0.0},
#  {'_id': ObjectId('600381203789f4ca7f3499a9'),
#   'ID': 745794558,
#   'name': 'Action drama sports boxing movie film mma vegas fiction ufc',
#   'category': 'Action',
#   'main_category': 'Film & Video',
#   'goal': 60000.0,
#   'launched': '2016-12-19 20:11:13',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 1910.0},
#  {'_id': ObjectId('600381203789f4ca7f3442d5'),
#   'ID': 770596738,
#   'name': '2020 Vision Ultra High End 4k Action Camera Sports Cam',
#   'category': 'Camera Equipment',
#   'main_category': 'Technology',
#   'goal': 25000.0,
#   'launched': '2017-04-20 22:48:37',
#   'state': 'failed',
#   'country': 'GB',
#   'usd_pledged_real': 2527.094355128666},
#  {'_id': ObjectId('600381203789f4ca7f33e86a'),
#   'ID': 1645109959,
#   'name': 'Vinci 2.0 - Worldï¿½s First Standalone AI Sports Headphones',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'goal': 20000.0,
#   'launched': '2017-11-15 19:00:42',
#   'state': 'live',
#   'country': 'US',
#   'usd_pledged_real': 724423.8},
#  {'_id': ObjectId('600381203789f4ca7f3488c6'),
#   'ID': 355654885,
#   'name': 'Omaha Blitz Football: Ages 8+, 2 to 4 plyr, Sports Card Game',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'goal': 15000.0,
#   'launched': '2016-02-01 22:40:11',
#   'state': 'failed',
#   'country': 'US',
#   'usd_pledged_real': 620.0}]
