# %% [markdown]
# # Projet
#
# ### Description du projet
#     - Création d'une application Web vous basant sur le package Flask.
#     - Récupération des données sur le web scrapées grâce à ce que vous aurez appris durant ce cours.
#     - Affichage des données de façon optimale, moteur de recherche, graphiques, etc.
#     - Utilisation d'une ou plusieurs bases de données abordées dans ce cours.
#     - Création d'une documentation technique et fonctionnelle.
#
# ### Description
#     -Site utilisé : https://www.allocine.fr/
#     -robot.txt : https://www.allocine.fr/robots.txt
#
#     -Récupération d'informations possibles :
#         (Scrap#1) Page : Top film (10x30 films par pages) :
#             Date/Durée/Genre/Note presse/Note spectateur/Nombre de votes/Synopsis/Budget/Langue/Nombre Récompense/Distributeur/Casting Principal/Réalisateur/Top critique Spectateur
#             (Scrap#2) Page Casting pour avoir la liste complète
#             (Scrap#3) Page des récompenses pour avoir le détail
#         (Scrap#1) Page : Films à l'affiche : Même données
#             (Scrap#4) Page Du box office pour relier à l'affiche
#         (Scrap#1) Page : Tous les films trié par popularité/Note presse/Note pop (15 films par page)
#     -Possible utilisation des données offrant une plus value avec ou sans graphe
#         -Histogramme des moyennes de note(pop ou presse)/Nombre de critique des films d'un réalisateur par année de sortie
#         -Diagramme circulaire des genres de film à l'affiche
#         -Graphe de l'évolution de box office d'un film à l'affiche sur la dernière semaine (à vérifier)
#         -Liste de film par paire de membre de casting
#         -Autres à définir
#
#     -Scraping : Utilisation de Scrapy préféré
#
# ### Objectif :
#     -Choisir ce que l'on veut récupérer comme données
#     -Prendre en compte le robot.txt
#     -Récupération des données
#     -En faire une base de donnée
#     -Nettoyer la base de donnée
#     -Mettre en relation les bases de données (si plusieurs)
#     -Manipuler les données
#     -Faire la page web
#     -Faire la page web de manière interactive
#
#
# ### Questions :
#     -Est-ce que l'on peut utiliser Dash pour la page Flask ?
#     -Comment interpréter le robot.txt
#     -La documentation c'est un User guide + Developpeur Guide ou c'est un rapport des étapes/difficultés etc...
#     -Plus value nécessaire ?
#
# ### Réponse :
#
# Par rapport à la valeur ajouté il faudrait ajouter quelque chose qui existe ailleur
# Faudrait rassembler les données de allociné et les lier aux données d’autres sites internets
# Exemple :
# Si on récupère le casting d’allociné on peut ajouter un scrap twitter pour associer au nombre de follower, on peut alors voir les films avec le plus de follower d’acteur et essayer de faire des liaisons théoriques
# Ca peut être autre chose et pas que des réseaux sociaux
# => faut ajouter une dimension/introduire une notion qui n’existe pas ailleur
# => Un peu du bonus mais très cool à faire ne plus
#
# Comment relier le nom des acteurs aux twitter ?
# 	=> Moteur de recherche, on récupère le pseudo, on va sur la page twitter puis les foll
# 	=> Rechercher un site qui recense les page twitter des personnalités
# 	=>
#
# Est-ce que l’on peut utiliser dash ?
# => Attendre les conseilles de Raphaël
#
#
# Comment interpréter le robot.txt
# => Rien n’est interdit, c’est juste que le site n’aimerait pas trop mais voilà on fait pas de bénéfices derrières donc on peut y aller

# %% [markdown]
# ## Récupération des données

# %%
#Vérification de l'installation de scrapy et importation
#!pip install scrapy

# %%
import scrapy
import pandas as pd
import numpy as np
import pymongo
import unicodedata

# %% [markdown]
# ## Projet stade
#
# ### Scraper allociné
# Prochaine étape :
#  #####  - ✓ Faire la commande pour récupérer la liste des titres dans la page meilleur film
# Dans le shell : <br>
# scrapy shell "https://www.allocine.fr/film/meilleurs/" <br>
# On a la liste des titres en marquant  <br>
# [response.css("#content-layout .mdl")[i].css("a::text").extract_first() for i in range (10)] <br>
#  #####  - ✓ Faire la class pour récupérer les titres + lien de la page des films
#  Classe faite => Projet/newscrawler/newscrawler/spiders/besttitlev1 <br>
#  Activation : cmd dans la page projet spider puis : scrapy crawl besttitlev1 <br>
#  Activation + save : cmd dans la page projet puis : scrapy crawl besttitlev1 -o titlelink.csv <br>
#
#  #####  - ✓ Faire  la commande pour scrap des informations recherchés sur chaque lien
#  Check dans la classe <br>
#  #####  - ✓ Faire la class de ce nouveau scrap
#  ######  ✓ Version 2
#  Classe faite => Projet/newscrawler/newscrawler/spiders/besttitlev2 <br>
#  Permet d'avoir les informations souhaitées mais une partie est stockée dans un fichier json <br>
#  La liste de liens de film est pris sur fichier csv de besttitlev1 <br>
#  La class n'est donc pas indépendante <br>
#  ######  ✓ Version 3
#  Classe faite => Projet/newscrawler/newscrawler/spiders/besttitlev3 <br>
#  Permet d'avoir proprement le titre, le synopsis, la date, la duree, le genre, le casting, le réalisateur, le nombre de note, le nombre de critique, la note publique, la note de press <br>
#  La liste de liens de film est pris sur fichier csv de besttitlev1 <br>
#  La class n'est donc pas indépendante <br>
#  Soucis au niveau des notes de presse absente qui font que 16 films ne passent pas <br>
#  ###### ✓Version  4
#  Objectif est de pouvoir avoir la fusion entre la version 1 et la version 3 de manière à ce que seule la version 4 soit nécessaire <br>
#  Object est également de virer le problème de la note de presse et des 16 films qui ne passent pas <br>
#  Classe faite => Projet/newscrawler/newscrawler/spiders/besttitlev3 <br>
#  Il manque juste le soucis de la note de presse <br>
#
#
#
#  ###  - Scraper boxoffice mojo
#  ###  - Mise en place dans une base de donnée Mongodb
#  ### - Mise en place du site Flask

# %%
client = pymongo.MongoClient("mongo")
database = client['projet']
collection = database['movies']

# %%
df_movies = pd.read_csv("rsltmoviesv1.csv")
print(df_movies.shape)
df_movies.head(50)
# Out:
# (273, 18)
#                                                 title  \
# 0                                        Pulp Fiction
# 1                                    Midnight Express
# 2                                             Warrior
# 3                                             Là-haut
# 4                                             Mustang
# 5                                Call Me By Your Name
# 6                                      Sueurs froides
# 7                                        Sixième Sens
# 8                                Le Discours d'un roi
# 9                                         Taxi Driver
# 10                                            Aladdin
# 11                                          Dragons 2
# 12                      Il était une fois en Amérique
# 13                                     Imitation Game
# 14                               Retour vers le futur
# 15                                       Citizen Kane
# ...

# %%
#Nettoyage de la base de donnée

#Nettoyage de la partie allociné
for i in range (df_movies.shape[0]):
    if (df_movies["catinfo"][i] != ' Titre original '):
        df_movies["titleint"][i] = unicodedata.normalize('NFD', df_movies["title"][i]).encode('ascii', 'ignore').decode('utf-8')
df_movies = df_movies.drop(columns=['catinfo'])

#Nettoyage de la partie boxofficemojo
for i in range (df_movies.shape[0]): 
    if ((df_movies['boxint'][i] == df_movies['boxtot'][i]) and ('$' not in df_movies['boxdom'][i][0])):
        df_movies['boxdom'][i] = np.NaN
    if ((type(df_movies['boxint'][i]) == float) and ('$' not in df_movies['boxdom'][i])):
        df_movies['boxdom'][i] = df_movies['boxtot'][i]
        df_movies['boxint'][i] = np.NaN
        
#Mise en forme
df_movies['rent'] = pd.Series(np.NaN, index=df_movies.index)
for i in range (df_movies.shape[0]):
    #Mise en place de la colonne rentabilité
    if (type(df_movies['boxtot'][i]) == float or type(df_movies['budget'][i]) == float):
        df_movies['rent'][i] = np.NaN
    else:
        df_movies['rent'][i] = float(df_movies['boxtot'][i][1:].replace(',','')) - float(df_movies['budget'][i][1:].replace(',',''))

    #Séparation des genres en liste de genre et non une string de genre
    df_movies['genre'][i] = df_movies['genre'][i].split(',')  
        
    #Mise en place du format date pour la colonne date
    df_movies['date'][i] = df_movies['date'][i].replace(' ', '-')
    if ('janvier' in df_movies['date'][i]): df_movies['date'][i] = df_movies['date'][i].replace('janvier', '01')
    elif ('février' in df_movies['date'][i]): df_movies['date'][i] = df_movies['date'][i].replace('février', '02')
    elif ('mars' in df_movies['date'][i]): df_movies['date'][i] = df_movies['date'][i].replace('mars', '03')
    elif ('avril' in df_movies['date'][i]): df_movies['date'][i] = df_movies['date'][i].replace('avril', '04')
    elif ('mai' in df_movies['date'][i]): df_movies['date'][i] = df_movies['date'][i].replace('mai', '05')
    elif ('juin' in df_movies['date'][i]): df_movies['date'][i] = df_movies['date'][i].replace('juin', '06')
    elif ('juillet' in df_movies['date'][i]): df_movies['date'][i] = df_movies['date'][i].replace('juillet', '07')
    elif ('août' in df_movies['date'][i]): df_movies['date'][i] = df_movies['date'][i].replace('août', '08')
    elif ('septembre' in df_movies['date'][i]): df_movies['date'][i] = df_movies['date'][i].replace('septembre', '09')
    elif ('octobre' in df_movies['date'][i]): df_movies['date'][i] = df_movies['date'][i].replace('octobre', '10')
    elif ('novembre' in df_movies['date'][i]): df_movies['date'][i] = df_movies['date'][i].replace('novembre', '11')
    elif ('décembre' in df_movies['date'][i]): df_movies['date'][i] = df_movies['date'][i].replace('décembre', '12')
df_movies['date'] = pd.to_datetime(df_movies['date'], format='%d-%m-%Y')
# Out:
# <ipython-input-18-927f222e4bb9>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movies["titleint"][i] = unicodedata.normalize('NFD', df_movies["title"][i]).encode('ascii', 'ignore').decode('utf-8')
# <ipython-input-18-927f222e4bb9>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movies['boxdom'][i] = df_movies['boxtot'][i]
# <ipython-input-18-927f222e4bb9>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df_movies.head(50)
# Out:
#                                                 title  \
# 0                                        Pulp Fiction
# 1                                    Midnight Express
# 2                                             Warrior
# 3                                             Là-haut
# 4                                             Mustang
# 5                                Call Me By Your Name
# 6                                      Sueurs froides
# 7                                        Sixième Sens
# 8                                Le Discours d'un roi
# 9                                         Taxi Driver
# 10                                            Aladdin
# 11                                          Dragons 2
# 12                      Il était une fois en Amérique
# 13                                     Imitation Game
# 14                               Retour vers le futur
# 15                                       Citizen Kane
# ...

# %%
def recherche(moviename):
    if (moviename in list(df_movies['title'])):
        return (df_movies.loc[list(df_movies['title']).index(moviename)])
    else:
        return ('Movie not found in database')

# %%
print(recherche('Slumdog Millionaire'))
print('-------------------')
print(recherche('Intouchable'))
# Out:
# title                                     Slumdog Millionaire
# titleint                                  Slumdog Millionaire
# synop       Jamal Malik, 18 ans, orphelin vivant dans les ...
# genre                  [Comédie dramatique, Comédie, Romance]
# date                                      2009-01-14 00:00:00
# duree                                                2h 00min
# cast             Dev Patel,Freida Pinto,Mia Drake,Anil Kapoor
# real                                              Danny Boyle
# nbrnote                                                 51296
# nbrcrit                                                  2985
# notepub                                                   4,3
# notepre                                                   3,5
# titleen                                   Slumdog Millionaire
# budget                                            $15,000,000
# boxdom                                           $141,319,928
# ...

# %%
collection.delete_many({})
collection.insert_many(df_movies.to_dict(orient='records'))

# %%
#### ZONE DE TEST #####

# %%
def sortfilm(collection, condition, genre, nbr):
    """
    Fonction permettant de faire intéragir la page Flask top film.
    Args:
        Str : Condition de sélection du top film
        Str : Filtre des films par genre
        Int : Nombre de film à afficher
    Return:
        Liste : Liste des films en fonction du top et du genre
    """
    genrefilter = ['Action', 'Animation', 'Aventure', 'Biopic', 'Comédie', 'Comédie dramatique', 'Comédie musicale', 'Documentaire', 'Drame', 'Epouvante-horreur', 'Famille', 'Fantastique', 'Guerre', 'Historique', 'Musical', 'Policier', 'Romance', 'Science fiction', 'Thriller', 'Western', 'Divers']
    #On trie en fonction de la condition
    if (condition == "bestpub"): 
        trie = [('notepub',-1), ('nbrnote',-1)]
        info = {'title':1, 'notepub':1, 'nbrnote':1, 'genre':1}
        legend = ['Titre', 'Genre(s)', 'Nombre de note', 'Note']
    elif (condition == "bestpre"):
        trie = [('notepre',-1), ('nbrnote',-1)]
        info = {'title':1, 'notepre':1, 'nbrnote':1, 'genre':1}
        legend = ['Titre', 'Genre(s)', 'Nombre de note', 'Note']
    elif (condition == "recent"):
        trie = [('date',-1)]
        info = {'title':1, 'date':1, 'genre':1}
        legend = ['Titre', 'Genre(s)', 'Date (Y-m-d)']
    elif (condition == "ancien"):
        trie = [('date',1)]
        info = {'title':1, 'date':1, 'genre':1}
        legend = ['Titre', 'Genre(s)', 'Date (Y-m-d)']
    elif (condition == "rent"):
        trie = [('rent',-1)]
        info = {'title':1, 'rent':1, 'genre':1}
        legend = ['Titre', 'Genre(s)', 'Rentabilité']
    elif (condition == "long"):
        trie = [('duree',-1)]
        info = {'title':1, 'duree':1, 'genre':1}
        legend = ['Titre', 'Genre(s)', 'Durée']
    elif (condition == "court"):
        trie = [('duree',1)]
        info = {'title':1, 'duree':1, 'genre':1}
        legend = ['Titre', 'Genre(s)', 'Durée']
    
    #On ajoute le filtre pour le genre
    if (genre != 'All') : genrefilter = [genre]
    
    #On récupère
    movielist = collection.find({'genre': {'$in' : genrefilter}}, info).sort(trie)
    
    data=[]
    data.append(legend)
    for k in (list(movielist)[:nbr]):
        data.append(list(k.values())[1:])
    if ('Date (Y-m-d)' in data[0]):
        for l in data[1:]: l[-1]=str(l[-1]).split()[0]
        
    #On affiche le résultat
    return(data)

# %%
def selectmovie(collection, moviename):
    """
    Fonction permettant d'avoir toutes les informations sur un film
    Args: 
        Str: Nom du film
    Returns:
        Liste : Toutes les informations sur le film
    """
    movieinfo = collection.aggregate([{'$match': {'title' : moviename}}])
    if (list(collection.aggregate([{'$match': {'title' : moviename}}])) == []):
        return("Movie not found")
    else:
        data = []
        data.append(list(list(movieinfo)[0].values())[1:])
        return(data)

# %%
movieinfo = collection.aggregate([{'$match': {'title' : "Forrest Gump"}}])
if (list(collection.aggregate([{'$match': {'title' : "Forrest Gump"}}])) == []):
    print("sd")
else:
    data = []
    data.append(list(list(movieinfo)[0].values())[1:])
data
collection.aggregate([{'$match': {'title' : "Forrest Gump"}}])

# %%
movieinfo = selectmovie(collection, 'Avsdfar')
movieinfo
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-28-cda41145acf5> in <module>
# ----> 1 movieinfo = selectmovie(collection, 'Avsdfar')
#       2 movieinfo
#
# <ipython-input-25-0d75d1c154ea> in selectmovie(collection, moviename)
#      12     else:
#      13         data = []
# ---> 14         data.append(list(list(movieinfo)[0].values())[1:])
#      15         return(data)
#
# IndexError: list index out of range

# %%
sortfilm(collection, 'bestpub', 'Action', 1)
# Out:
# [['Titre', 'Genre(s)', 'Nombre de note', 'Note'],
#  ['The Dark Knight, Le Chevalier Noir', ['Action', 'Thriller'], 91527, '4,5']]
